# %% [markdown]
# # Demo: Plot Phase Tensor Maps

# %%
import os, sys

print (os.path.sep)
# Out:
# /

# %%
#1) set env variables PYTHONPATH and MTPYPATH before starting jupyther notebook,
# OR alternatively
#2) do the following two statements. Then it will all works fine.
mtpydir='E:/Github/mtpy2'  #'/Softlab/Githubz/mtpy'
sys.path.insert(0,mtpydir)   # python path for import 
os.environ['MTPYPATH']=mtpydir #Data  resources configuration

# %%
% matplotlib inline

# import the required modules
import glob
import os

#from mtpy.tests.common import MTPY_DEVELOPMENT_TEST_DATA
#from mtpy.imaging.plot_phase_tensor_maps_with_tipper import PlotPhaseTensorMaps
from mtpy.imaging.plotptmaps  import PlotPhaseTensorMaps

# %%
# read the list of edi file names
# The following reads all the edi files in MTPY_DEVELOPMENT_TEST_DATA directory
MTPY_DEVELOPMENT_TEST_DATA='/g/data/ha3/fxz547/mtpy2/examples/data/edi_files/georgina'
edi_file_list = glob.glob(os.path.join(MTPY_DEVELOPMENT_TEST_DATA,
                                       '*.edi'))

# %%
print(MTPY_DEVELOPMENT_TEST_DATA)

# %%
# How many edi files? (one edi per station)
print(len(edi_file_list))
# Out:
# 9

# %%
# frequency to plot
plot_freq =0.1

# parameters describing ellipses
ellipse_dict = {'size': 0.02, 'colorby': 'phimin', 'range': (0, 90, 1), 'cmap': 'mt_bl2gr2rd'}

# parameters describing the induction vector arrows
arrow_dict = {'size': 0.2,
              'lw': 0.01,
              'head_width': 0.002,
              'head_length': 0.002,
              'threshold': 0.8,
              'direction': 0}

# parameters describing the arrow legend (should be self explanatory)
arrow_legend_dict = {'position': 'upper right',
                     'fontpad': 0.0025,
                     'xborderpad': 0.07,
                     'yborderpad': 0.015}

m = PlotPhaseTensorMaps(fn_list=edi_file_list,
                                plot_freq=plot_freq,
                                arrow_legend_dict=arrow_legend_dict,
                                ftol=0.2,
                                xpad=0.02,
                                plot_tipper='yri',
                                arrow_dict=arrow_dict,
                                ellipse_dict=ellipse_dict,
                                figsize=(10, 12))
# Out:
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB02
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB08
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB01
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB04
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB03
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB09
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB07
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB06
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB05
# Reading 9 stations
# Could not plot image
# Did not find 0.1 Hz for station GB02
# Did not find 0.1 Hz for station GB01
# Did not find 0.1 Hz for station GB04
# Did not find 0.1 Hz for station GB03
# Did not find 0.1 Hz for station GB05

# %%
pt1 = PlotPhaseTensorMaps(fn_list=edi_file_list, 
                          plot_freq=100, 
                          plot_tipper='yri',
                          fig_size=[10, 10],
                          font_size=14,
                          fig_dpi=50
                         )
# Out:
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB02
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB08
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB01
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB04
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB03
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB09
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB07
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB06
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB05
# Reading 9 stations
# Could not plot image
# Did not find 100 Hz for station GB02
# Did not find 100 Hz for station GB01
# Did not find 100 Hz for station GB04
# Did not find 100 Hz for station GB03
# Did not find 100 Hz for station GB05

# %%
# change arrow properties and replot
pt1.arrow.arrow_size = .2
pt1.arrow.arrow_head_width = 0.00125
pt1.arrow.arrow_head_length = 0.0025
pt1.arrow.arrow_lw = .01
pt1.fig_size = [10, 12]
pt1.redraw_plot()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-21-9db4ffa07973> in <module>()
#       1 # change arrow properties and replot
# ----> 2 pt1.arrow.arrow_size = .2
#       3 pt1.arrow.arrow_head_width = 0.00125
#       4 pt1.arrow.arrow_head_length = 0.0025
#       5 pt1.arrow.arrow_lw = .01
#
# AttributeError: 'PlotPhaseTensorMaps' object has no attribute 'arrow'

# %%
# plot in km scale
pt2 = PlotPhaseTensorMaps(fn_list=edi_file_list, 
                          plot_freq=100, 
                          plot_tipper='yri',
                          fig_size=[10, 10],
                          font_size=14,
                          fig_dpi=50,
                          mapscale='km'
                        )
# Out:
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB02
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB08
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB01
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB04
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB03
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB09
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB07
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB06
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB05
# Reading 9 stations
# Could not plot image
# Did not find 100 Hz for station GB02
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-23-17068209a47f> in <module>()
#       6                           font_size=14,
#       7                           fig_dpi=50,
# ----> 8                           mapscale='km'
#       9                         )
#
# /g/data/ha3/fxz547/mtpy2/mtpy/imaging/plotptmaps.pyc in __init__(self, **kwargs)
#     575         self.plot_yn = kwargs.pop('plot_yn', 'y')
#     576         if self.plot_yn == 'y':
# --> 577             self.plot()
#     578
#     579     #---need to rotate data on setting rotz
#
# /g/data/ha3/fxz547/mtpy2/mtpy/imaging/plotptmaps.pyc in plot(self)
#     738
#     739                     else:
# --> 740                         if zone1!=zone:
#     741                             print 'Zone change at station '+mt.station
#     742                             if zone1[0:2] == zone[0:2]:
#
# UnboundLocalError: local variable 'zone1' referenced before assignment

# %%
# plot in m scale
pt2 = PlotPhaseTensorMaps(fn_list=edi_file_list, 
                          plot_freq=100, 
                          plot_tipper='yri',
                          fig_size=[10, 10],
                          font_size=14,
                          fig_dpi=50,
                          mapscale='m'
                        )
# Out:
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB02
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB08
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB01
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB04
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB03
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB09
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB07
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB06
# Ordered arrays to be arranged from high to low frequency
# Could not find any Tipper data.
# Read in edi file for station GB05
# Reading 9 stations
# Could not plot image
# Did not find 100 Hz for station GB02
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-24-8ab90f14c016> in <module>()
#       6                           font_size=14,
#       7                           fig_dpi=50,
# ----> 8                           mapscale='m'
#       9                         )
#
# /g/data/ha3/fxz547/mtpy2/mtpy/imaging/plotptmaps.pyc in __init__(self, **kwargs)
#     575         self.plot_yn = kwargs.pop('plot_yn', 'y')
#     576         if self.plot_yn == 'y':
# --> 577             self.plot()
#     578
#     579     #---need to rotate data on setting rotz
#
# /g/data/ha3/fxz547/mtpy2/mtpy/imaging/plotptmaps.pyc in plot(self)
#     711                         #check to make sure the zone is the same this needs
#     712                         #to be more rigorously done
# --> 713                         if zone1!=zone:
#     714                             print 'Zone change at station '+mt.station
#     715                             if zone1[0:2] == zone[0:2]:
#
# UnboundLocalError: local variable 'zone1' referenced before assignment
