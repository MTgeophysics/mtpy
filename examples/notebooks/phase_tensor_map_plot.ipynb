# %% [markdown]
# # Demo: Plot Phase Tensor Maps
#
# ## Fei Zhang
# ## 2016-12-19
#
# - Note:frequency must be selected correctly, otherwise could have issue with zone1 assigment, zero-sized array erros

# %%
import os, sys

# print (os.path.sep)

#Supress default INFO logging

# %%
#1) set env variables PYTHONPATH and MTPYPATH before starting jupyther notebook,
# Alternatively
#2) do the following two statements. Then it will all works fine.

mtpydir='/Softlab/Githubz/mtpy2' 
#'/g/data/ha3/fxz547/Githubz/mtpy2'  
mtpydir='E:/Githubz/mtpy2'  
sys.path.insert(0,mtpydir)
os.environ['MTPYPATH']=mtpydir

# %%
% matplotlib inline

# import the required modules
import glob
import os

#from mtpy.tests.common import MTPY_DEVELOPMENT_TEST_DATA
#from mtpy.imaging.plot_phase_tensor_maps_with_tipper import PlotPhaseTensorMaps
from mtpy.imaging.plotptmaps  import PlotPhaseTensorMaps
# Out:
# INFO:root:module file: E:\Githubz\mtpy2\mtpy\utils\mtpylog.pyc
# INFO:root:Effective yaml configuration file E:\Githubz\mtpy2\mtpy\utils\logging.yml

# %%
# read the list of edi file names
# The following reads all the edi files in MTPY_DEVELOPMENT_TEST_DATA directory
MTPY_DEVELOPMENT_TEST_DATA=os.path.join(mtpydir, 'examples/data/edi_files/georgina')  # plots partially OK
MTPY_DEVELOPMENT_TEST_DATA=os.path.join(mtpydir, 'examples/data/edi_files/')

MTPY_DEVELOPMENT_TEST_DATA='E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s'
edi_file_list = glob.glob(os.path.join(MTPY_DEVELOPMENT_TEST_DATA, '*.edi'))

# %%
print(MTPY_DEVELOPMENT_TEST_DATA)
# Out:
# E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s

# %%
# How many edi files? (one edi per station)
print(len(edi_file_list))
# Out:
# 98

# %%
# frequency to plot
plot_freq =0.1

# parameters describing ellipses
ellipse_dict = {'size': 0.04, 'colorby': 'phimin', 'range': (0, 90, 1), 'cmap': 'mt_bl2gr2rd'}

# parameters describing the induction vector arrows
arrow_dict = {'size': 0.2,
              'lw': 0.01,
              'head_width': 0.002,
              'head_length': 0.001,
              'threshold': 0.8,
              'direction': 0}

# parameters describing the arrow legend (should be self explanatory)
arrow_legend_dict = {'position': 'upper right',
                     'fontpad': 0.0025,
                     'xborderpad': 0.07,
                     'yborderpad': 0.015}

m = PlotPhaseTensorMaps(fn_list=edi_file_list,
                                plot_freq=plot_freq,
                                arrow_legend_dict=arrow_legend_dict,
                                ftol=0.2,
                                xpad=0.02,
                                plot_tipper='yri',
                                arrow_dict=arrow_dict,
                                ellipse_dict=ellipse_dict,
                                figsize=(10, 12))
# Out:
# 2017-03-10 15:36:08,898 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC002.edi
# 2017-03-10 15:36:08,903 - mtpy.core.edi - INFO - Read in edi file for station VIC002
# 2017-03-10 15:36:08,904 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC003.edi
# 2017-03-10 15:36:08,911 - mtpy.core.edi - INFO - Read in edi file for station VIC003
# 2017-03-10 15:36:08,913 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC004.edi
# 2017-03-10 15:36:08,918 - mtpy.core.edi - INFO - Read in edi file for station VIC004
# 2017-03-10 15:36:08,920 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC005.edi
# 2017-03-10 15:36:08,927 - mtpy.core.edi - INFO - Read in edi file for station VIC005
# 2017-03-10 15:36:08,928 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC006.edi
# 2017-03-10 15:36:08,934 - mtpy.core.edi - INFO - Read in edi file for station VIC006
# 2017-03-10 15:36:08,936 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC007.edi
# 2017-03-10 15:36:08,940 - mtpy.core.edi - INFO - Read in edi file for station VIC007
# 2017-03-10 15:36:08,943 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC008.edi
# 2017-03-10 15:36:08,948 - mtpy.core.edi - INFO - Read in edi file for station VIC008
# 2017-03-10 15:36:08,950 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC009.edi
# 2017-03-10 15:36:08,956 - mtpy.core.edi - INFO - Read in edi file for station VIC009
# 2017-03-10 15:36:08,959 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC010.edi
# 2017-03-10 15:36:08,967 - mtpy.core.edi - INFO - Read in edi file for station VIC010
# 2017-03-10 15:36:08,969 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC011.edi
# 2017-03-10 15:36:08,976 - mtpy.core.edi - INFO - Read in edi file for station VIC011
# 2017-03-10 15:36:08,980 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC012.edi
# 2017-03-10 15:36:08,987 - mtpy.core.edi - INFO - Read in edi file for station VIC012
# 2017-03-10 15:36:08,993 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC013.edi
# 2017-03-10 15:36:09,002 - mtpy.core.edi - INFO - Read in edi file for station VIC013
# 2017-03-10 15:36:09,003 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC014.edi
# 2017-03-10 15:36:09,007 - mtpy.core.edi - INFO - Read in edi file for station VIC014
# 2017-03-10 15:36:09,010 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC015.edi
# 2017-03-10 15:36:09,019 - mtpy.core.edi - INFO - Read in edi file for station VIC015
# 2017-03-10 15:36:09,020 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC016.edi
# 2017-03-10 15:36:09,026 - mtpy.core.edi - INFO - Read in edi file for station VIC016
# 2017-03-10 15:36:09,028 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC017.edi
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# E:/Githubz/mtpy2\mtpy\imaging\mtplottools.py:820: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if edi_obj.Tipper.tipper == None:
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# 2017-03-10 15:36:09,035 - mtpy.core.edi - INFO - Read in edi file for station VIC017
# 2017-03-10 15:36:09,036 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC018.edi
# 2017-03-10 15:36:09,040 - mtpy.core.edi - INFO - Read in edi file for station VIC018
# 2017-03-10 15:36:09,042 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC019.edi
# 2017-03-10 15:36:09,048 - mtpy.core.edi - INFO - Read in edi file for station VIC019
# 2017-03-10 15:36:09,049 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC021.edi
# 2017-03-10 15:36:09,053 - mtpy.core.edi - INFO - Read in edi file for station VIC021
# 2017-03-10 15:36:09,055 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC022.edi
# 2017-03-10 15:36:09,059 - mtpy.core.edi - INFO - Read in edi file for station VIC022
# 2017-03-10 15:36:09,062 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC023.edi
# 2017-03-10 15:36:09,066 - mtpy.core.edi - INFO - Read in edi file for station VIC023
# 2017-03-10 15:36:09,068 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC024.edi
# 2017-03-10 15:36:09,072 - mtpy.core.edi - INFO - Read in edi file for station VIC024
# 2017-03-10 15:36:09,073 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC025.edi
# 2017-03-10 15:36:09,078 - mtpy.core.edi - INFO - Read in edi file for station VIC025
# 2017-03-10 15:36:09,079 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC026.edi
# 2017-03-10 15:36:09,085 - mtpy.core.edi - INFO - Read in edi file for station VIC026
# 2017-03-10 15:36:09,086 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC027.edi
# 2017-03-10 15:36:09,092 - mtpy.core.edi - INFO - Read in edi file for station VIC027
# 2017-03-10 15:36:09,092 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VI
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Could not plot image
# Did not find 0.1 Hz for station VIC002
# Did not find 0.1 Hz for station VIC004
# Did not find 0.1 Hz for station VIC005
# Did not find 0.1 Hz for station VIC006
# Did not find 0.1 Hz for station VIC007
# Did not find 0.1 Hz for station VIC008
# Did not find 0.1 Hz for station VIC009
# Did not find 0.1 Hz for station VIC010
# Did not find 0.1 Hz for station VIC012
# Did not find 0.1 Hz for station VIC013
# Did not find 0.1 Hz for station VIC014
# Did not find 0.1 Hz for station VIC015
# Did not find 0.1 Hz for station VIC016
# Did not find 0.1 Hz for station VIC017
# Did not find 0.1 Hz for station VIC021
# Did not find 0.1 Hz for station VIC033
# Did not find 0.1 Hz for station VIC034
# Did not find 0.1 Hz for station VIC035
# Did not find 0.1 Hz for station VIC051
# Did not find 0.1 Hz for station VIC054
# Did not find 0.1 Hz for station VIC062
# Did not find 0.1 Hz for station VIC063
# Did not find 0.1 Hz for station VIC069
# Did not find 0.1 Hz for station VIC096
# Did not find 0.1 Hz for station VIC64R

# %%
pt1 = PlotPhaseTensorMaps(fn_list=edi_file_list, 
                          plot_freq=plot_freq, 
                          plot_tipper='yri',
                          fig_size=[10, 10],
                          font_size=14,
                          fig_dpi=50
                         )
# Out:
# 2017-03-10 15:36:10,487 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC002.edi
# 2017-03-10 15:36:10,493 - mtpy.core.edi - INFO - Read in edi file for station VIC002
# 2017-03-10 15:36:10,496 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC003.edi
# 2017-03-10 15:36:10,502 - mtpy.core.edi - INFO - Read in edi file for station VIC003
# 2017-03-10 15:36:10,503 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC004.edi
# 2017-03-10 15:36:10,509 - mtpy.core.edi - INFO - Read in edi file for station VIC004
# 2017-03-10 15:36:10,510 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC005.edi
# 2017-03-10 15:36:10,517 - mtpy.core.edi - INFO - Read in edi file for station VIC005
# 2017-03-10 15:36:10,520 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC006.edi
# 2017-03-10 15:36:10,526 - mtpy.core.edi - INFO - Read in edi file for station VIC006
# 2017-03-10 15:36:10,529 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC007.edi
# 2017-03-10 15:36:10,536 - mtpy.core.edi - INFO - Read in edi file for station VIC007
# 2017-03-10 15:36:10,540 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC008.edi
# 2017-03-10 15:36:10,546 - mtpy.core.edi - INFO - Read in edi file for station VIC008
# 2017-03-10 15:36:10,548 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC009.edi
# 2017-03-10 15:36:10,553 - mtpy.core.edi - INFO - Read in edi file for station VIC009
# 2017-03-10 15:36:10,561 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC010.edi
# 2017-03-10 15:36:10,568 - mtpy.core.edi - INFO - Read in edi file for station VIC010
# 2017-03-10 15:36:10,569 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC011.edi
# 2017-03-10 15:36:10,575 - mtpy.core.edi - INFO - Read in edi file for station VIC011
# 2017-03-10 15:36:10,576 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC012.edi
# 2017-03-10 15:36:10,582 - mtpy.core.edi - INFO - Read in edi file for station VIC012
# 2017-03-10 15:36:10,584 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC013.edi
# 2017-03-10 15:36:10,588 - mtpy.core.edi - INFO - Read in edi file for station VIC013
# 2017-03-10 15:36:10,591 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC014.edi
# 2017-03-10 15:36:10,596 - mtpy.core.edi - INFO - Read in edi file for station VIC014
# 2017-03-10 15:36:10,598 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VI
- mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC062.edi
# 2017-03-10 15:36:10,894 - mtpy.core.edi - INFO - Read in edi file for station VIC062
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
# ...
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# 2017-03-10 15:36:11,098 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC099.edi
# 2017-03-10 15:36:11,105 - mtpy.core.edi - INFO - Read in edi file for station VIC099
# 2017-03-10 15:36:11,105 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC100.edi
# 2017-03-10 15:36:11,111 - mtpy.core.edi - INFO - Read in edi file for station VIC100
# 2017-03-10 15:36:11,112 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC64R.edi
# 2017-03-10 15:36:11,119 - mtpy.core.edi - INFO - Read in edi file for station VIC64R
# 2017-03-10 15:36:11,121 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC65R.edi
# 2017-03-10 15:36:11,128 - mtpy.core.edi - INFO - Read in edi file for station VIC65R
# 2017-03-10 15:36:11,128 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC67R.edi
# 2017-03-10 15:36:11,137 - mtpy.core.edi - INFO - Read in edi file for station vic67R
# 2017-03-10 15:36:11,138 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC82R.edi
# 2017-03-10 15:36:11,145 - mtpy.core.edi - INFO - Read in edi file for station VIC82R
# 2017-03-10 15:36:11,147 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC84R.edi
# 2017-03-10 15:36:11,154 - mtpy.core.edi - INFO - Read in edi file for station VIC84R
# Reading 98 stations
# Could not plot image
# Did not find 0.1 Hz for station VIC002
# Did not find 0.1 Hz for station VIC004
# Did not find 0.1 Hz for station VIC005
# Did not find 0.1 Hz for station VIC006
# Did not find 0.1 Hz for station VIC007
# Did not find 0.1 Hz for station VIC008
# Did not find 0.1 Hz for station VIC009
# Did not find 0.1 Hz for station VIC010
# Did not find 0.1 Hz for station VIC012
# Did not find 0.1 Hz for station VIC013
# Did not find 0.1 Hz for station VIC014
# Did not find 0.1 Hz for station VIC015
# Did not find 0.1 Hz for station VIC016
# Did not find 0.1 Hz for station VIC017
# Did not find 0.1 Hz for station VIC019
# Did not find 0.1 Hz for station VIC021
# Did not find 0.1 Hz for station VIC033
# Did not find 0.1 Hz for station VIC034
# Did not find 0.1 Hz for station VIC035
# Did not find 0.1 Hz for station VIC051
# Did not find 0.1 Hz for station VIC054
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Did not find 0.1 Hz for station VIC062
# Did not find 0.1 Hz for station VIC063
# Did not find 0.1 Hz for station VIC069
# Did not find 0.1 Hz for station VIC096
# Did not find 0.1 Hz for station VIC64R

# %%
# change arrow properties and replot

# pt1.arrow.arrow_size = .5
# pt1.arrow.arrow_head_width = 0.00125
# pt1.arrow.arrow_head_length = 0.0025
# pt1.arrow.arrow_lw = .01

pt1.arrow_size = .2
pt1.arrow_head_width = 0.0125
pt1.arrow_head_length = 0.025
pt1.arrow_lw = .1
pt1.fig_size = [10, 12]
pt1.redraw_plot()
# Out:
# Could not plot image
# Did not find 0.1 Hz for station VIC002
# Did not find 0.1 Hz for station VIC004
# Did not find 0.1 Hz for station VIC005
# Did not find 0.1 Hz for station VIC006
# Did not find 0.1 Hz for station VIC007
# Did not find 0.1 Hz for station VIC008
# Did not find 0.1 Hz for station VIC009
# Did not find 0.1 Hz for station VIC010
# Did not find 0.1 Hz for station VIC012
# Did not find 0.1 Hz for station VIC013
# Did not find 0.1 Hz for station VIC014
# Did not find 0.1 Hz for station VIC015
# Did not find 0.1 Hz for station VIC016
# Did not find 0.1 Hz for station VIC017
# Did not find 0.1 Hz for station VIC019
# Did not find 0.1 Hz for station VIC021
# Did not find 0.1 Hz for station VIC033
# Did not find 0.1 Hz for station VIC034
# Did not find 0.1 Hz for station VIC035
# Did not find 0.1 Hz for station VIC051
# Did not find 0.1 Hz for station VIC054
# Did not find 0.1 Hz for station VIC062
# Did not find 0.1 Hz for station VIC063
# Did not find 0.1 Hz for station VIC069
# Did not find 0.1 Hz for station VIC096
# Did not find 0.1 Hz for station VIC64R

# %%
# plot in km scale
pt2 = PlotPhaseTensorMaps(fn_list=edi_file_list, 
                          plot_freq=plot_freq, 
                          plot_tipper='yri',
                          fig_size=[10, 10],
                          font_size=14,
                          fig_dpi=50,
                          mapscale='km'
                        )
# Out:
# 2017-03-10 15:36:12,654 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC002.edi
# 2017-03-10 15:36:12,658 - mtpy.core.edi - INFO - Read in edi file for station VIC002
# 2017-03-10 15:36:12,660 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC003.edi
# 2017-03-10 15:36:12,665 - mtpy.core.edi - INFO - Read in edi file for station VIC003
# 2017-03-10 15:36:12,670 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC004.edi
# 2017-03-10 15:36:12,676 - mtpy.core.edi - INFO - Read in edi file for station VIC004
# 2017-03-10 15:36:12,677 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC005.edi
# 2017-03-10 15:36:12,684 - mtpy.core.edi - INFO - Read in edi file for station VIC005
# 2017-03-10 15:36:12,690 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC006.edi
# 2017-03-10 15:36:12,694 - mtpy.core.edi - INFO - Read in edi file for station VIC006
# 2017-03-10 15:36:12,700 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC007.edi
# 2017-03-10 15:36:12,709 - mtpy.core.edi - INFO - Read in edi file for station VIC007
# 2017-03-10 15:36:12,711 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC008.edi
# 2017-03-10 15:36:12,724 - mtpy.core.edi - INFO - Read in edi file for station VIC008
# 2017-03-10 15:36:12,726 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC009.edi
# 2017-03-10 15:36:12,733 - mtpy.core.edi - INFO - Read in edi file for station VIC009
# 2017-03-10 15:36:12,736 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC010.edi
# 2017-03-10 15:36:12,742 - mtpy.core.edi - INFO - Read in edi file for station VIC010
# 2017-03-10 15:36:12,743 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC011.edi
# 2017-03-10 15:36:12,750 - mtpy.core.edi - INFO - Read in edi file for station VIC011
# 2017-03-10 15:36:12,752 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC012.edi
# 2017-03-10 15:36:12,756 - mtpy.core.edi - INFO - Read in edi file for station VIC012
# 2017-03-10 15:36:12,757 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC013.edi
# 2017-03-10 15:36:12,763 - mtpy.core.edi - INFO - Read in edi file for station VIC013
# 2017-03-10 15:36:12,763 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC014.edi
# 2017-03-10 15:36:12,769 - mtpy.core.edi - INFO - Read in edi file for station VIC014
# 2017-03-10 15:36:12,769 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC015.edi
# 2017-03-10 15:36:12,775 - mtpy.core.edi - INFO - Read in edi file for station VIC015
# 2017-03-10 15:36:12,776 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC016.edi
# 2017-03-10 15:36:12,780 - mtpy.core.edi - INFO - Read in edi file for station VIC016
# 2017-03-10 15:36:12,782 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC017.edi
# 2017-03-10 15:36:12,786 - mtpy.core.edi - INFO - Read in edi file for station VIC017
# 2017-03-10 15:36:12,789 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC018.edi
# 2017-03-10 15:36:12,793 - mtpy.core.edi - INFO - Read in edi file for station VIC018
# 2017-03-10 15:36:12,795 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC019.edi
# 2017-03-10 15:36:12,799 - mtpy.core.edi - INFO - Read in edi file for station VIC019
# 2017-03-10 15:36:12,799 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC021.edi
# 2017-03-10 15:36:12,805 - mtpy.core.edi - INFO - Read in edi file for station VIC021
# 2017-03-10 15:36:12,805 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC022.edi
# 2017-03-10 15:36:12,811 - mtpy.core.edi - INFO - Read in edi file for station VIC022
# 2017-03-10 15:36:12,812 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC023.edi
# 2017-03-10 15:36:12,816 - mtpy.core.edi - INFO - Read in edi file for station VIC023
# 2017-03-10 15:36:12,818 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC024.edi
# 2017-03-10 15:36:12,822 - mtpy.core.edi - INFO - Read in edi file for station VIC024
# 2017-03-10 15:36:12,823 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC025.edi
# 2017-03-10 15:36:12,828 - mtpy.core.edi - INFO - Read in edi file for station VIC025
# 2017-03-10 15:36:12,829 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC026.edi
# 2017-03-10 15:36:12,835 - mtpy.core.edi - INFO - Read in edi file for station VIC026
# 2017-03-10 15:36:12,835 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC027.edi
# 2017-03-10 15:36:12,841 - mtpy.core.edi - INFO - Read in edi file for station VIC027
# 2017-03-10 15:36:12,842 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC028.edi
# 2017-03-10 15:36:12,846 - mtpy.core.edi - INFO - Read in edi file for station VIC028
# 2017-03-10 15:36:12,848 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC029.edi
# 2017-03-10 15:36:12,854 - mtpy.core.edi - INFO - Read in edi file for station VIC029
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# 2017-03-10 15:36:12,855 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC030.edi
# 2017-03-10 15:36:12,861 - mtpy.core.edi - INFO - Read in edi file for station VIC030
# 2017-03-10 15:36:12,862 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC031.edi
# 2017-03-10 15:36:12,868 - mtpy.core.edi - INFO - Read in edi file for station VIC031
# 2017-03-10 15:36:12,868 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC032.edi
# 2017-03-10 15:36:12,875 - mtpy.core.edi - INFO - Read in edi file for station VIC032
# 2017-03-10 15:36:12,877 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC033.edi
# 2017-03-10 15:36:12,881 - mtpy.core.edi - INFO - Read in edi file for station VIC033
# 2017-03-10 15:36:12,882 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC034.edi
# 2017-03-10 15:36:12,890 - mtpy.core.edi - INFO - Read in edi file for station VIC034
# 2017-03-10 15:36:12,891 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC035.edi
# 2017-03-10 15:36:12,894 - mtpy.core.edi - INFO - Read in edi file for station VIC035
# 2017-03-10 15:36:12,895 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC036.edi
# 2017-03-10 15:36:12,901 - mtpy.core.edi - INFO - Read in edi file for station VIC036
# 2017-03-10 15:36:12,903 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC037.edi
# 2017-03-10 15:36:12,907 - mtpy.core.edi - INFO - Read in edi file for station VIC037
# 2017-03-10 15:36:12,908 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC038.edi
# 2017-03-10 15:36:12,914 - mtpy.core.edi - INFO - Read in edi file for station VIC038
# 2017-03-10 15:36:12,915 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC039.edi
# 2017-03-10 15:36:12,921 - mtpy.core.edi - INFO - Read in edi file for station VIC039
# 2017-03-10 15:36:12,921 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC040.edi
# 2017-03-10 15:36:12,927 - mtpy.core.edi - INFO - Read in edi file for station VIC040
# 2017-03-10 15:36:12,927 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC041.edi
# 2017-03-10 15:36:12,934 - mtpy.core.edi - INFO - Read in edi file for station VIC041
# 2017-03-10 15:36:12,934 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VI
- mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC099.edi
# 2017-03-10 15:36:13,286 - mtpy.core.edi - INFO - Read in edi file for station VIC099
# 2017-03-10 15:36:13,289 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC100.edi
# 2017-03-10 15:36:13,293 - mtpy.core.edi - INFO - Read in edi file for station VIC100
# 2017-03-10 15:36:13,296 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC64R.edi
# 2017-03-10 15:36:13,303 - mtpy.core.edi - INFO - Read in edi file for station VIC64R
# 2017-03-10 15:36:13,305 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC65R.edi
# 2017-03-10 15:36:13,312 - mtpy.core.edi - INFO - Read in edi file for station VIC65R
# 2017-03-10 15:36:13,313 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC67R.edi
# 2017-03-10 15:36:13,322 - mtpy.core.edi - INFO - Read in edi file for station vic67R
# 2017-03-10 15:36:13,322 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC82R.edi
# 2017-03-10 15:36:13,331 - mtpy.core.edi - INFO - Read in edi file for station VIC82R
# 2017-03-10 15:36:13,332 - mtpy.core.edi - INFO - Reading the edi file E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\VIC84R.edi
# 2017-03-10 15:36:13,339 - mtpy.core.edi - INFO - Read in edi file for station VIC84R
# Reading 98 stations
# Could not plot image
# Did not find 0.1 Hz for station VIC002
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 182
# Traceback (most recent call last):
#   File "C:\Anaconda2\lib\logging\handlers.py", line 77, in emit
#     self.doRollover()
#   File "C:\Anaconda2\lib\logging\handlers.py", line 142, in doRollover
#     os.rename(self.baseFilename, dfn)
# WindowsError: [Error 32] The process cannot access the file because it is being used by another process
# Logged from file edi.py, line 215
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-10-00b30e14efa8> in <module>()
#       6                           font_size=14,
#       7                           fig_dpi=50,
# ----> 8                           mapscale='km'
#       9                         )
#
# E:/Githubz/mtpy2\mtpy\imaging\plotptmaps.pyc in __init__(self, **kwargs)
#     575         self.save_fn = kwargs.pop('save_fn', "/c/tmp")
#     576         if self.plot_yn == 'y':
# --> 577             self.plot()
#     578             # self.save_figure(self.save_fn, file_format='png')
#     579
#
# E:/Githubz/mtpy2\mtpy\imaging\plotptmaps.pyc in plot(self)
#     754
#     755                     else:
# --> 756                         if zone1 != zone:
#     757                             print 'Zone change at station ' + mt.station
#     758                             if zone1[0:2] == zone[0:2]:
#
# UnboundLocalError: local variable 'zone1' referenced before assignment

# %%
# plot in m scale
pt2 = PlotPhaseTensorMaps(fn_list=edi_file_list, 
                          plot_freq=plot_freq, 
                          plot_tipper='yri',
                          fig_size=[10, 10],
                          font_size=14,
                          fig_dpi=50,
                          mapscale='m'
                        )

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl


mpl.rcParams['lines.linewidth'] = 2
# mpl.rcParams['lines.color'] = 'r'

mpl.rcParams['figure.figsize']=[20,10]

# %%
# http://stackoverflow.com/questions/14432557/matplotlib-scatter-plot-with-different-text-at-each-data-point
# http://matplotlib.org/examples/mplot3d/text3d_demo.html
y=[2.56422, 3.77284,3.52623,3.51468,3.02199]
z=[0.15, 0.3, 0.45, 0.6, 0.75]
n=['MT1','MT2',393,203,'MT123']

fig, ax = plt.subplots()
ax.scatter(z, y,s=40, c='r',marker='^')

for i, txt in enumerate(n):
    ax.annotate(txt, (z[i],y[i]))

# %%
ax.scatter?
