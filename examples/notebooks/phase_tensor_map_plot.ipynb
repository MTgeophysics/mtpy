# %% [markdown]
# # Demo: Plot Phase Tensor Maps
#
# ## Fei Zhang
# ## 2016-12-19
#
# - Note:frequency must be selected correctly, otherwise could have issue with zone1 assigment, zero-sized array erros

# %%
import os, sys

print (os.path.sep)
# Out:
# /

# %%
#1) set env variables PYTHONPATH and MTPYPATH before starting jupyther notebook,
# OR alternatively
#2) do the following two statements. Then it will all works fine.
mtpydir='/g/data/ha3/fxz547/Githubz/mtpy2'  #'E:/Github/mtpy2'  #'/Softlab/Githubz/mtpy'
sys.path.insert(0,mtpydir)   # python path for import 
os.environ['MTPYPATH']=mtpydir #Data  resources configuration

# %%
% matplotlib inline

# import the required modules
import glob
import os

#from mtpy.tests.common import MTPY_DEVELOPMENT_TEST_DATA
#from mtpy.imaging.plot_phase_tensor_maps_with_tipper import PlotPhaseTensorMaps
from mtpy.imaging.plotptmaps  import PlotPhaseTensorMaps

# %%
# read the list of edi file names
# The following reads all the edi files in MTPY_DEVELOPMENT_TEST_DATA directory
MTPY_DEVELOPMENT_TEST_DATA=os.path.join(mtpydir, 'examples/data/edi_files/georgina')  # plots partially OK
MTPY_DEVELOPMENT_TEST_DATA=os.path.join(mtpydir, 'examples/data/edi_files/')
edi_file_list = glob.glob(os.path.join(MTPY_DEVELOPMENT_TEST_DATA, '*.edi'))

# %%
print(MTPY_DEVELOPMENT_TEST_DATA)
# Out:
# /g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/

# %%
# How many edi files? (one edi per station)
print(len(edi_file_list))
# Out:
# 15

# %%
# frequency to plot
plot_freq =0.1

# parameters describing ellipses
ellipse_dict = {'size': 0.02, 'colorby': 'phimin', 'range': (0, 90, 1), 'cmap': 'mt_bl2gr2rd'}

# parameters describing the induction vector arrows
arrow_dict = {'size': 0.2,
              'lw': 0.01,
              'head_width': 0.002,
              'head_length': 0.001,
              'threshold': 0.8,
              'direction': 0}

# parameters describing the arrow legend (should be self explanatory)
arrow_legend_dict = {'position': 'upper right',
                     'fontpad': 0.0025,
                     'xborderpad': 0.07,
                     'yborderpad': 0.015}

m = PlotPhaseTensorMaps(fn_list=edi_file_list,
                                plot_freq=plot_freq,
                                arrow_legend_dict=arrow_legend_dict,
                                ftol=0.2,
                                xpad=0.02,
                                plot_tipper='yri',
                                arrow_dict=arrow_dict,
                                ellipse_dict=ellipse_dict,
                                figsize=(10, 12))
# Out:
# Could not find any Tipper data.
# Read in edi file for station pb30
# Could not find any Tipper data.
# Read in edi file for station pb43
# Could not find any Tipper data.
# Read in edi file for station pb39
# Could not find any Tipper data.
# Read in edi file for station pb42
# Could not find any Tipper data.
# Read in edi file for station pb35
# Could not find any Tipper data.
# Read in edi file for station pb23
# Could not find any Tipper data.
# Read in edi file for station pb37
# Could not find any Tipper data.
# Read in edi file for station pb27
# Could not find any Tipper data.
# Read in edi file for station pb44
# Could not find any Tipper data.
# Read in edi file for station pb33
# Could not find any Tipper data.
# Read in edi file for station pb40
# Could not find any Tipper data.
# Read in edi file for station pb29
# Could not find any Tipper data.
# Read in edi file for station pb25
# Could not find any Tipper data.
# Read in edi file for station pb32
# Could not find any Tipper data.
# Read in edi file for station pb41
# Reading 15 stations
# Could not plot image

# %%
pt1 = PlotPhaseTensorMaps(fn_list=edi_file_list, 
                          plot_freq=plot_freq, 
                          plot_tipper='yri',
                          fig_size=[10, 10],
                          font_size=14,
                          fig_dpi=50
                         )
# Out:
# Could not find any Tipper data.
# Read in edi file for station pb30
# Could not find any Tipper data.
# Read in edi file for station pb43
# Could not find any Tipper data.
# Read in edi file for station pb39
# Could not find any Tipper data.
# Read in edi file for station pb42
# Could not find any Tipper data.
# Read in edi file for station pb35
# Could not find any Tipper data.
# Read in edi file for station pb23
# Could not find any Tipper data.
# Read in edi file for station pb37
# Could not find any Tipper data.
# Read in edi file for station pb27
# Could not find any Tipper data.
# Read in edi file for station pb44
# Could not find any Tipper data.
# Read in edi file for station pb33
# Could not find any Tipper data.
# Read in edi file for station pb40
# Could not find any Tipper data.
# Read in edi file for station pb29
# Could not find any Tipper data.
# Read in edi file for station pb25
# Could not find any Tipper data.
# Read in edi file for station pb32
# Could not find any Tipper data.
# Read in edi file for station pb41
# Reading 15 stations
# Could not plot image

# %%
# change arrow properties and replot

# pt1.arrow.arrow_size = .5
# pt1.arrow.arrow_head_width = 0.00125
# pt1.arrow.arrow_head_length = 0.0025
# pt1.arrow.arrow_lw = .01

pt1.arrow_size = .2
pt1.arrow_head_width = 0.0125
pt1.arrow_head_length = 0.025
pt1.arrow_lw = .1
pt1.fig_size = [10, 12]
pt1.redraw_plot()
# Out:
# Could not plot image
# Did not find 100 Hz for station GB02
# Did not find 100 Hz for station GB01
# Did not find 100 Hz for station GB04
# Did not find 100 Hz for station GB03
# Did not find 100 Hz for station GB05

# %%
# plot in km scale
pt2 = PlotPhaseTensorMaps(fn_list=edi_file_list, 
                          plot_freq=plot_freq, 
                          plot_tipper='yri',
                          fig_size=[10, 10],
                          font_size=14,
                          fig_dpi=50,
                          mapscale='km'
                        )
# Out:
# Could not find any Tipper data.
# Read in edi file for station pb30
# Could not find any Tipper data.
# Read in edi file for station pb43
# Could not find any Tipper data.
# Read in edi file for station pb39
# Could not find any Tipper data.
# Read in edi file for station pb42
# Could not find any Tipper data.
# Read in edi file for station pb35
# Could not find any Tipper data.
# Read in edi file for station pb23
# Could not find any Tipper data.
# Read in edi file for station pb37
# Could not find any Tipper data.
# Read in edi file for station pb27
# Could not find any Tipper data.
# Read in edi file for station pb44
# Could not find any Tipper data.
# Read in edi file for station pb33
# Could not find any Tipper data.
# Read in edi file for station pb40
# Could not find any Tipper data.
# Read in edi file for station pb29
# Could not find any Tipper data.
# Read in edi file for station pb25
# Could not find any Tipper data.
# Read in edi file for station pb32
# Could not find any Tipper data.
# Read in edi file for station pb41
# Reading 15 stations
# Could not plot image
# ('FZ debug:', '54J')

# %%
# plot in m scale
pt2 = PlotPhaseTensorMaps(fn_list=edi_file_list, 
                          plot_freq=plot_freq, 
                          plot_tipper='yri',
                          fig_size=[10, 10],
                          font_size=14,
                          fig_dpi=50,
                          mapscale='m'
                        )
# Out:
# Could not find any Tipper data.
# Read in edi file for station pb30
# Could not find any Tipper data.
# Read in edi file for station pb43
# Could not find any Tipper data.
# Read in edi file for station pb39
# Could not find any Tipper data.
# Read in edi file for station pb42
# Could not find any Tipper data.
# Read in edi file for station pb35
# Could not find any Tipper data.
# Read in edi file for station pb23
# Could not find any Tipper data.
# Read in edi file for station pb37
# Could not find any Tipper data.
# Read in edi file for station pb27
# Could not find any Tipper data.
# Read in edi file for station pb44
# Could not find any Tipper data.
# Read in edi file for station pb33
# Could not find any Tipper data.
# Read in edi file for station pb40
# Could not find any Tipper data.
# Read in edi file for station pb29
# Could not find any Tipper data.
# Read in edi file for station pb25
# Could not find any Tipper data.
# Read in edi file for station pb32
# Could not find any Tipper data.
# Read in edi file for station pb41
# Reading 15 stations
# Could not plot image
# ('ii= ', 0)
# ('FZ debug:', '54J')
# ('ii= ', 1)
# ('ii= ', 2)
# ('ii= ', 3)
# ('ii= ', 4)
# ('ii= ', 5)
# ('ii= ', 6)
# ('ii= ', 7)
# ('ii= ', 8)
# ('ii= ', 9)
# ('ii= ', 10)
# ('ii= ', 11)
# ('ii= ', 12)
# ('ii= ', 13)
# ('ii= ', 14)
