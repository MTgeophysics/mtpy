# %% [markdown]
# # Demo: Plot Phase Tensor Pseudo Section
#
# ## Fei Zhang
# ## 2016-12-19

# %%
% matplotlib inline

# import the required modules
import os
import glob
import sys


#1) set env variables PYTHONPATH and MTPYPATH before starting jupyther notebook,
# OR alternatively
#2) do the following two statements. Then it will all works fine.
mtpydir='/g/data/ha3/fxz547/Githubz/mtpy2'  #'E:/Github/mtpy2'  #'/Softlab/Githubz/mtpy'
sys.path.insert(0,mtpydir)   # python path for import 
os.environ['MTPYPATH']=mtpydir #Data  resources configuration

# %%
import mtpy.imaging.mtplot as mtplot
from mtpy.imaging.mtplottools import MTArrows, MTEllipse
from mtpy.tests.common import MTPY_DEVELOPMENT_TEST_DATA
from mtpy.imaging.phase_tensor_pseudo_section_plot import PlotPhaseTensorPseudoSection
from mtpy.imaging.plotptpseudosection import PlotPhaseTensorPseudoSection

# %%
# We have a list of edi files for this demo in the repo

MTPY_DEVELOPMENT_TEST_DATA=os.path.join(mtpydir, 'examples/data/edi_files/georgina')  # plots partially OK
MTPY_DEVELOPMENT_TEST_DATA=os.path.join(mtpydir, 'examples/data/edi_files/')
edi_file_list = glob.glob(os.path.join(MTPY_DEVELOPMENT_TEST_DATA, '*.edi'))

# %%
print(edi_file_list)
# Out:
# ['/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb30c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb43c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb39c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb42c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb35c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb23c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb37c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb27c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb44c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb33c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb40c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb29c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb25c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb32c.edi', '/g/data/ha3/fxz547/Githubz/mtpy2/examples/data/edi_files/pb41c.edi']

# %%
# Define the ellipse and arrow properties
ellipse_dict = {'range': (20, 70), 'cmap': 'mt_bl2gr2rd',
                'colorby': 'phimin', 'size': 10}
ellipse = MTEllipse(ellipse_dict=ellipse_dict)
arrow = MTArrows({'size': 60, 'head_length': 4})

# %%
# Plot the phase tensor pseudo section
pt1 = PlotPhaseTensorPseudoSection(
    #data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=1,  # plot an ellipse at every frequency value
    plot_tipper='yri',
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[10, 12]
    )
# Out:
# Could not find any Tipper data.
# Read in edi file for station pb30
# Could not find any Tipper data.
# Read in edi file for station pb43
# Could not find any Tipper data.
# Read in edi file for station pb39
# Could not find any Tipper data.
# Read in edi file for station pb42
# Could not find any Tipper data.
# Read in edi file for station pb35
# Could not find any Tipper data.
# Read in edi file for station pb23
# Could not find any Tipper data.
# Read in edi file for station pb37
# Could not find any Tipper data.
# Read in edi file for station pb27
# Could not find any Tipper data.
# Read in edi file for station pb44
# Could not find any Tipper data.
# Read in edi file for station pb33
# Could not find any Tipper data.
# Read in edi file for station pb40
# Could not find any Tipper data.
# Read in edi file for station pb29
# /g/data/ha3/fxz547/Githubz/mtpy2/mtpy/imaging/mtplottools.py:824: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if edi_obj.Tipper.tipper == None:
# Could not find any Tipper data.
# Read in edi file for station pb25
# Could not find any Tipper data.
# Read in edi file for station pb32
# Could not find any Tipper data.
# Read in edi file for station pb41
# Reading 15 stations
# -------------------------
# phimin min = 6.51
# phimin max = 54.62
# -------------------------

# %%
# Change some properties and replot
pt1.ellipse_freq = 2  # plot ellipse at every second frequency
pt1.arrow_size = 50  # change arrow size to 50
pt1.fig_size=[10, 12]
pt1.font_size=14
pt1.redraw_plot()
# Out:
# -------------------------
# phimin min = 6.51
# phimin max = 54.62
# -------------------------

# %%
# change arrow properties
arrow.arrow_size = 100
arrow.arrow_head_width = 3
arrow.arrow_head_length = 4

# plot every 3rd ellipse
pt1 = PlotPhaseTensorPseudoSection(
    #edi_file_list,
    data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=5,  #=3 plot every 3rd ellipse
    plot_tipper='yri', # plot real and imaginary tipper arrows
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[10, 12],
    font_size=14,
    )
# Out:
# Could not find any Tipper data.
# Read in edi file for station pb30
# Could not find any Tipper data.
# Read in edi file for station pb43
# Could not find any Tipper data.
# Read in edi file for station pb39
# Could not find any Tipper data.
# Read in edi file for station pb42
# Could not find any Tipper data.
# Read in edi file for station pb35
# Could not find any Tipper data.
# Read in edi file for station pb23
# Could not find any Tipper data.
# Read in edi file for station pb37
# Could not find any Tipper data.
# Read in edi file for station pb27
# Could not find any Tipper data.
# Read in edi file for station pb44
# Could not find any Tipper data.
# Read in edi file for station pb33
# Could not find any Tipper data.
# Read in edi file for station pb40
# Could not find any Tipper data.
# Read in edi file for station pb29
# Could not find any Tipper data.
# Read in edi file for station pb25
# Could not find any Tipper data.
# Read in edi file for station pb32
# Could not find any Tipper data.
# Read in edi file for station pb41
# Reading 15 stations
# -------------------------
# phimin min = 6.51
# phimin max = 54.62
# -------------------------

# %%
# Colorby 'skew'
ellipse.ellipse_colorby = 'skew'
arrow.arrow_size = 50
# plot every 3rd ellipse
pt1 = PlotPhaseTensorPseudoSection(
    #edi_file_list,
    data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=3,  # plot every 3rd ellipse
    plot_tipper='yri', # plot real and imaginary tipper arrows
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[10, 12],
    font_size=14
   )
# Out:
# Could not find any Tipper data.
# Read in edi file for station pb30
# Could not find any Tipper data.
# Read in edi file for station pb43
# Could not find any Tipper data.
# Read in edi file for station pb39
# Could not find any Tipper data.
# Read in edi file for station pb42
# Could not find any Tipper data.
# Read in edi file for station pb35
# Could not find any Tipper data.
# Read in edi file for station pb23
# Could not find any Tipper data.
# Read in edi file for station pb37
# Could not find any Tipper data.
# Read in edi file for station pb27
# Could not find any Tipper data.
# Read in edi file for station pb44
# Could not find any Tipper data.
# Read in edi file for station pb33
# Could not find any Tipper data.
# Read in edi file for station pb40
# Could not find any Tipper data.
# Read in edi file for station pb29
# Could not find any Tipper data.
# Read in edi file for station pb25
# Could not find any Tipper data.
# Read in edi file for station pb32
# Could not find any Tipper data.
# Read in edi file for station pb41
# Reading 15 stations
# -------------------------
# phimin min = 6.51
# phimin max = 54.62
# -------------------------

# %%
# Colorby 'normalized_skew'
ellipse.ellipse_colorby = 'normalized_skew'
# change arrow size
arrow.arrow_size = 40
# plot every 4th ellipse
pt1 = PlotPhaseTensorPseudoSection(
    #edi_file_list,
    data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=4,  # plot every 4th ellipse
    plot_tipper='yri', # plot real and imaginary tipper arrows
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[10, 12],
    font_size=14
    )
# Out:
# Could not find any Tipper data.
# Read in edi file for station pb30
# Could not find any Tipper data.
# Read in edi file for station pb43
# Could not find any Tipper data.
# Read in edi file for station pb39
# Could not find any Tipper data.
# Read in edi file for station pb42
# Could not find any Tipper data.
# Read in edi file for station pb35
# Could not find any Tipper data.
# Read in edi file for station pb23
# Could not find any Tipper data.
# Read in edi file for station pb37
# Could not find any Tipper data.
# Read in edi file for station pb27
# Could not find any Tipper data.
# Read in edi file for station pb44
# Could not find any Tipper data.
# Read in edi file for station pb33
# Could not find any Tipper data.
# Read in edi file for station pb40
# Could not find any Tipper data.
# Read in edi file for station pb29
# Could not find any Tipper data.
# Read in edi file for station pb25
# Could not find any Tipper data.
# Read in edi file for station pb32
# Could not find any Tipper data.
# Read in edi file for station pb41
# Reading 15 stations
# -------------------------
# phimin min = 6.51
# phimin max = 54.62
# -------------------------

# %%
# Colorby 'ellipticity'
ellipse.ellipse_colorby = 'ellipticity'

# plot every 4th ellipse
pt1 = PlotPhaseTensorPseudoSection(
    #edi_file_list,
    data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=4,  # plot every 4th ellipse
    plot_tipper='yri', # plot real and imaginary tipper arrows
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[10, 12],
    font_size=14
    )
# Out:
# Could not find any Tipper data.
# Read in edi file for station pb30
# Could not find any Tipper data.
# Read in edi file for station pb43
# Could not find any Tipper data.
# Read in edi file for station pb39
# Could not find any Tipper data.
# Read in edi file for station pb42
# Could not find any Tipper data.
# Read in edi file for station pb35
# Could not find any Tipper data.
# Read in edi file for station pb23
# Could not find any Tipper data.
# Read in edi file for station pb37
# Could not find any Tipper data.
# Read in edi file for station pb27
# Could not find any Tipper data.
# Read in edi file for station pb44
# Could not find any Tipper data.
# Read in edi file for station pb33
# Could not find any Tipper data.
# Read in edi file for station pb40
# Could not find any Tipper data.
# Read in edi file for station pb29
# Could not find any Tipper data.
# Read in edi file for station pb25
# Could not find any Tipper data.
# Read in edi file for station pb32
# Could not find any Tipper data.
# Read in edi file for station pb41
# Reading 15 stations
# -------------------------
# phimin min = 6.51
# phimin max = 54.62
# -------------------------
