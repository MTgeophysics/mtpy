# %% [markdown]
# # Demo: Plot Phase Tensor Pseudo Section
#
# ## Fei Zhang
# ## 2016-12-19

# %%
% matplotlib inline

# import the required modules
import os
import glob
import sys


#1) set env variables PYTHONPATH and MTPYPATH before starting jupyther notebook,
# Alternatively
#2) do the following two statements. Then it will all works fine.


mtpydir='/Softlab/Githubz/mtpy2' 
#'/g/data/ha3/fxz547/Githubz/mtpy2'  
mtpydir='E:/Githubz/mtpy2'  

sys.path.insert(0,mtpydir)   # python path for import 
os.environ['MTPYPATH']=mtpydir #Data  resources configuration

#Supress default INFO logging

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
import mtpy.imaging.mtplot as mtplot
from mtpy.imaging.mtplottools import MTArrows, MTEllipse

from mtpy.imaging.phase_tensor_pseudo_section_plot import PlotPhaseTensorPseudoSection
from mtpy.imaging.plotptpseudosection import PlotPhaseTensorPseudoSection

# %%
# We have a list of edi files for this demo in the repo

MTPY_DEVELOPMENT_TEST_DATA=os.path.join(mtpydir, 'examples/data/edi_files/georgina')  # plots partially OK
MTPY_DEVELOPMENT_TEST_DATA=os.path.join(mtpydir, 'examples/data/edi_files/')
MTPY_DEVELOPMENT_TEST_DATA=os.path.join(mtpydir, 'tests/data/edifiles/')


MTPY_DEVELOPMENT_TEST_DATA='E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s'
edi_file_list = glob.glob(os.path.join(MTPY_DEVELOPMENT_TEST_DATA, '*.edi'))

# %%
print(edi_file_list)
# Out:
# ['E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC002.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC003.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC004.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC005.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC006.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC007.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC008.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC009.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC010.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC011.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC012.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC013.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC014.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC015.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC016.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC017.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC018.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC019.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC021.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC022.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC023.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC024.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC025.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC026.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC027.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC028.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC029.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC030.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC031.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC032.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC033.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC034.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC035.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC036.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC037.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC038.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC039.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC040.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC041.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC042.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC043.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC044.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC045.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC046.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC047.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC048.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC049.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC050.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC051.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC052.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC053.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC054.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC055.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC056.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC057.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC059.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC060.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC061.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC062.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC063.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC066.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC068.edi', 'E:/Datasets/MT_Datasets/GA_UA_edited_10s-10000s\\VIC069.edi', 'E:/Datasets/MT_Datasets/GA_UA ...

# %%
# Define the ellipse and arrow properties
ellipse_dict = {'range': (20, 70), 'cmap': 'mt_bl2gr2rd',
                'colorby': 'phimin', 'size': 10}
ellipse = MTEllipse(ellipse_dict=ellipse_dict)
arrow = MTArrows({'size': 60, 'head_length': 4})

# %%
# Plot the phase tensor pseudo section
pt1 = PlotPhaseTensorPseudoSection(
    #data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=1,  # plot an ellipse at every frequency value
    plot_tipper='yri',
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[15, 20]
    )
# Out:
# Reading 98 stations
# -------------------------
# phimin min = -81.29
# phimin max = 79.75
# -------------------------

# %%
# Change some properties and replot
pt1.ellipse_freq = 2  # plot ellipse at every second frequency
pt1.arrow_size = 50  # change arrow size to 50
pt1.fig_size=[10, 20]
pt1.font_size=14
pt1.redraw_plot()
# Out:
# -------------------------
# phimin min = -81.29
# phimin max = 79.75
# -------------------------

# %%
# change arrow properties
arrow.arrow_size = 100
arrow.arrow_head_width = 3
arrow.arrow_head_length = 4

# plot every 3rd ellipse
pt1 = PlotPhaseTensorPseudoSection(
    #edi_file_list,
    data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=5,  #=3 plot every 3rd ellipse
    plot_tipper='yri', # plot real and imaginary tipper arrows
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[10, 20],
    font_size=14,
    )
# Out:
# Reading 98 stations
# -------------------------
# phimin min = -81.29
# phimin max = 79.75
# -------------------------

# %%
# Colorby 'skew'
ellipse.ellipse_colorby = 'skew'
arrow.arrow_size = 50
# plot every 3rd ellipse
pt1 = PlotPhaseTensorPseudoSection(
    #edi_file_list,
    data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=3,  # plot every 3rd ellipse
    plot_tipper='yri', # plot real and imaginary tipper arrows
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[10, 20],
    font_size=14
   )
# Out:
# Reading 98 stations
# -------------------------
# phimin min = -81.29
# phimin max = 79.75
# -------------------------

# %%
# Colorby 'normalized_skew'
ellipse.ellipse_colorby = 'normalized_skew'
# change arrow size
arrow.arrow_size = 40
# plot every 4th ellipse
pt1 = PlotPhaseTensorPseudoSection(
    #edi_file_list,
    data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=4,  # plot every 4th ellipse
    plot_tipper='yri', # plot real and imaginary tipper arrows
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[10, 20],
    font_size=14
    )
# Out:
# Reading 98 stations
# -------------------------
# phimin min = -81.29
# phimin max = 79.75
# -------------------------

# %%
# Colorby 'ellipticity'
ellipse.ellipse_colorby = 'ellipticity'

# plot every 4th ellipse
pt1 = PlotPhaseTensorPseudoSection(
    #edi_file_list,
    data_type='z',
    ellipse=ellipse,
    arrow=arrow,
    fn_list=edi_file_list,
    tscale='frequency',
    ellipse_freq=4,  # plot every 4th ellipse
    plot_tipper='yri', # plot real and imaginary tipper arrows
    stretch=(1500, 35),
    scale_arrow=False,
    fig_size=[10, 20],
    font_size=14
    )
# Out:
# Reading 98 stations
# -------------------------
# phimin min = -81.29
# phimin max = 79.75
# -------------------------
