# %% [markdown]
# # Plotting Phase Tensor Maps

# %% [markdown]
# * Import necessary modules

# %%
# make all plots plot inline
# %matplotlib inline

# %%
import os
import mtpy.imaging.mtplot as mtplot

# %% [markdown]
# * create a list of .edi files

# %%
edi_path = os.path.join(os.getcwd(), 'data', 'HalfSpaceSQC')
edi_list = [os.path.join(edi_path, edi_fn) for edi_fn in os.listdir(edi_path) if edi_fn.endswith('.edi')]

# %% [markdown]
# * plot the phase tensor maps using mtplot.plot_pt_maps module

# %%
ptm = mtplot.plot_pt_map(fn_list=edi_list)
# Out:
# Got latitude from reflat for par00
# Got longitude from reflon for par00
# Got elevation from refelev for par00
# Read in edi file for station par00
# Got latitude from reflat for par01
# Got longitude from reflon for par01
# Got elevation from refelev for par01
# Read in edi file for station par01
# Got latitude from reflat for par010
# Got longitude from reflon for par010
# Got elevation from refelev for par010
# Read in edi file for station par010
# Got latitude from reflat for par01ew
# Got longitude from reflon for par01ew
# Got elevation from refelev for par01ew
# Read in edi file for station par01ew
# Got latitude from reflat for par02
# Got longitude from reflon for par02
# Got elevation from refelev for par02
# Read in edi file for station par02
# Got latitude from reflat for par02ew
# Got longitude from reflon for par02ew
# Got elevation from refelev for par02ew
# Read in edi file for station par02ew
# Got latitude from reflat for par03
# Got longitude from reflon for par03
# Got elevation from refelev for par03
# Read in edi file for station par03
# Got latitude from reflat for par03ew
# Got longitude from reflon for par03ew
# Got elevation from refelev for par03ew
# Read in edi file for station par03ew
# Got latitude from reflat for par04
# Got longitude from reflon for par04
# Got elevation from refelev for par04
# Read in edi file for station par04
# Got latitude from reflat for par04ew
# Got longitude from reflon for par04ew
# Got elevation from refelev for par04ew
# Read in edi file for station par04ew
# Got latitude from reflat for par05ew
# Got longitude from reflon for par05ew
# Got elevation from refelev for par05ew
# Read in edi file for station par05ew
# Got latitude from reflat for par06
# Got longitude from reflon for par06
# Got elevation from refelev for par06
# Read in edi file for station par06
# Got latitude from reflat for par06ew
# Got longitude from reflon for par06ew
# Got elevation from refelev for par06ew
# Read in edi file for station par06ew
# Got latitude from reflat for par07
# Got longitude from reflon for par07
# Got elevation from refelev for par07
# Read in edi file for station par07
# Got latitude from reflat for par07ew
# Got longitude from reflon for par07ew
# Got elevation from refelev for par07ew
# Read in edi file for station par07ew
# Got latitude from reflat for par08
# Got longitude from reflon for par08
# Got elevation from refelev for par08
# Read in edi file for station par08
# Got latitude from reflat for par08ew
# Got longitude from reflon for par08ew
# Got elevation from refelev for par08ew
# Read in edi file for station par08ew
# Got latitude from reflat for par09
# Got longitude from reflon for par09
# Got elevation from refelev for par09
# Read in edi file for station par09
# Got latitude from reflat for par09ew
# Got longitude from reflon for par09ew
# Got elevation from refelev for par09ew
# Read in edi file for station par09ew
# Got latitude from reflat for par10
# Got longitude from reflon for par10
# Got elevation from refelev for par10
# Read in edi file for station par10
# Got latitude from reflat for par100
# Got longitude from reflon for par100
# Got elevation from refelev for par100
# Read in edi file for station par100
# Got latitude from reflat for par101
# Got longitude from reflon for par101
# Got elevation from refelev for par101
# Read in edi file for station par101
# Got latitude from reflat for par1010
# Got longitude from reflon for par1010
# Got elevation from refelev for par1010
# Read in edi file for station par1010
# Got latitude from reflat for par102
# Got longitude from reflon for par102
# Got elevation from refelev for par102
# Read in edi file for station par102
# Got latitude from reflat for par103
# Got longitude from reflon for par103
# Got elevation from refelev for par103
# Read in edi file for station par103
# Got latitude from reflat for par104
# Got longitude from reflon for par104
# Got elevation from refelev for par104
# Read in edi file for station par104
# Got latitude from reflat for par106
# Got longitude from reflon for par106
# Got elevation from refelev for par106
# Read in edi file for station par106
# Got latitude from reflat for par107
# Got longitude from reflon for par107
# Got elevation from refelev for par107
# Read in edi file for station par107
# Got latitude from reflat for par108
# Got longitude from reflon for par108
# Got elevation from refelev for par108
# Read in edi file for station par108
# Got latitude from reflat for par109
# Got longitude from reflon for par109
# Got elevation from refelev for par109
# Read in edi file for station par109
# Got latitude from reflat for par10ew
# Got longitude from reflon for par10ew
# Got elevation from refelev for par10ew
# Read in edi file for station par10ew
# Read in edi file for station par10ew
# Read in edi file for station par10ew
# Got latitude from reflat for par11
# Got longitude from reflon for par11
# Got elevation from refelev for par11
# Read in edi file for station par11
# Got latitude from reflat for par110
# Got longitude from reflon for par110
# Got elevation from refelev for par110
# Read in edi file for station par110
# Got latitude from reflat for par1101
# Got longitude from reflon for par1101
# Got elevation from refelev for par1101
# Read in edi file for station par1101
# Got latitude from reflat for par1102
# Got longitude from reflon for par1102
# Got elevation from refelev for par1102
# Read in edi file for station par1102
# Got latitude from reflat for par1103
# Got longitude from reflon for par1103
# Got elevation from refelev for par1103
# Read in edi file for station par1103
# Got latitude from reflat for par1104
# Got longitude from reflon for par1104
# Got elevation from refelev for par1104
# Read in edi file for station par1104
# Got latitude from reflat for par1105
# Got longitude from reflon for par1105
# Got elevation from refelev for par1105
# Read in edi file for station par1105
# Got latitude from reflat for par1106
# Got longitude from reflon for par1106
# Got elevation from refelev for par1106
# Read in edi file for station par1106
# Got latitude from reflat for par1107
# Got longitude from reflon for par1107
# Got elevation from refelev for par1107
# Read in edi file for station par1107
# Got latitude from reflat for par1108
# Got longitude from reflon for par1108
# Got elevation from refelev for par1108
# Read in edi file for station par1108
# Got latitude from reflat for par1109
# Got longitude from reflon for par1109
# Got elevation from refelev for par1109
# Read in edi file for station par1109
# Got latitude from reflat for par1110
# Got longitude from reflon for par1110
# Got elevation from refelev for par1110
# Read in edi file for station par1110
# Got latitude from reflat for par1111
# Got longitude from reflon for par1111
# Got elevation from refelev for par1111
# Read in edi file for station par1111
# Got latitude from reflat for par1112
# Got longitude from reflon for par1112
# Got elevation from refelev for par1112
# Read in edi file for station par1112
# Got latitude from reflat for par1113
# Got longitude from reflon for par1113
# Got elevation from refelev for par1113
# Read in edi file for station par1113
# Got latitude from reflat for par1114
# Got longitude from reflon for par1114
# Got elevation from refelev for par1114
# Read in edi file for station par1114
# Got latitude from reflat for par1115
# Got longitude from reflon for par1115
# Got elevation from refelev for par1115
# Read in edi file for station par1115
# Got latitude from reflat for par1116
# Got longitude from reflon for par1116
# Got elevation from refelev for par1116
# Read in edi file for station par1116
# Got latitude from reflat for par1117_0
# Got longitude from reflon for par1117_0
# Got elevation from refelev for par1117_0
# Read in edi file for station par1117_0
# Got latitude from reflat for par1117_1
# Got longitude from reflon for par1117_1
# Got elevation from refelev for par1117_1
# Read in edi file for station par1117_1
# Got latitude from reflat for par1118
# Got longitude from reflon for par1118
# Got elevation from refelev for par1118
# Read in edi file for station par1118
# Got latitude from reflat for par1119
# Got longitude from reflon for par1119
# Got elevation from refelev for par1119
# Read in edi file for station par1119
# Got latitude from reflat for par11ew
# Got longitude from reflon for par11ew
# Got elevation from refelev for par11ew
# Read in edi file for station par11ew
# Got latitude from reflat for par12
# Got longitude from reflon for par12
# Got elevation from refelev for par12
# Read in edi file for station par12
# Got latitude from reflat for par1201
# Got longitude from reflon for par1201
# Got elevation from refelev for par1201
# Read in edi file for station par1201
# Got latitude from reflat for par1202
# Got longitude from reflon for par1202
# Got elevation from refelev for par1202
# Read in edi file for station par1202
# Got latitude from reflat for par1203
# Got longitude from reflon for par1203
# Got elevation from refelev for par1203
# Read in edi file for station par1203
# Got latitude from reflat for par1204
# Got longitude from reflon for par1204
# Got elevation from refelev for par1204
# Read in edi file for station par1204
# Got latitude from reflat for par1205
# Got longitude from reflon for par1205
# Got elevation from refelev for par1205
# Read in edi file for station par1205
# Got latitude from reflat for par1206
# Got longitude from reflon for par1206
# Got elevation from refelev for par1206
# Read in edi file for station par1206
# Got latitude from reflat for par1207
# Got longitude from reflon for par1207
# Got elevation from refelev for par1207
# Read in edi file for station par1207
# Got latitude from reflat for par1208
# Got longitude from reflon for par1208
# Got elevation from refelev for par1208
# Read in edi file for station par1208
# Got latitude from reflat for par1209
# Got longitude from reflon for par1209
# Got elevation from refelev for par1209
# Read in edi file for station par1209
# Got latitude from reflat for par1210
# Got longitude from reflon for par1210
# Got elevation from refelev for par1210
# Read in edi file for station par1210
# Got latitude from reflat for par1211
# Got longitude from reflon for par1211
# Got elevation from refelev for par1211
# Read in edi file for station par1211
# Got latitude from reflat for par1212
# Got longitude from reflon for par1212
# Got elevation from refelev for par1212
# Read in edi file for station par1212
# Got latitude from reflat for par1213
# Got longitude from reflon for par1213
# Got elevation from refelev for par1213
# Read in edi file for station par1213
# Got latitude from reflat for par1214
# Got longitude from reflon for par1214
# Got elevation from refelev for par1214
# Read in edi file for station par1214
# Got latitude from reflat for par1215_0
# Got longitude from reflon for par1215_0
# Got elevation from refelev for par1215_0
# Read in edi file for station par1215_0
# Got latitude from reflat for par1215_1
# Got longitude from reflon for par1215_1
# Got elevation from refelev for par1215_1
# Read in edi file for station par1215_1
# Got latitude from reflat for par1216
# Got longitude from reflon for par1216
# Got elevation from refelev for par1216
# Read in edi file for station par1216
# Got latitude from reflat for par1217
# Got longitude from reflon for par1217
# Got elevation from refelev for par1217
# Read in edi file for station par1217
# Got latitude from reflat for par1218
# Got longitude from reflon for par1218
# Got elevation from refelev for par1218
# Read in edi file for station par1218
# Got latitude from reflat for par1219
# Got longitude from reflon for par1219
# Got elevation from refelev for par1219
# Read in edi file for station par1219
# Got latitude from reflat for par12ew
# Got longitude from reflon for par12ew
# Got elevation from refelev for par12ew
# Read in edi file for station par12ew
# Got latitude from reflat for par13
# Got longitude from reflon for par13
# Got elevation from refelev for par13
# Read in edi file for station par13
# Got latitude from reflat for par13ew
# Got longitude from reflon for par13ew
# Got elevation from refelev for par13ew
# Read in edi file for station par13ew
# Got latitude from reflat for par14
# Got longitude from reflon for par14
# Got elevation from refelev for par14
# Read in edi file for station par14
# Got latitude from reflat for par14ew
# Got longitude from reflon for par14ew
# Got elevation from refelev for par14ew
# Read in edi file for station par14ew
# Got latitude from reflat for par15ew
# Got longitude from reflon for par15ew
# Got elevation from refelev for par15ew
# Read in edi file for station par15ew
# Got latitude from reflat for par16
# Got longitude from reflon for par16
# Got elevation from refelev for par16
# Read in edi file for station par16
# Got latitude from reflat for par16ew
# Got longitude from reflon for par16ew
# Got elevation from refelev for par16ew
# Read in edi file for station par16ew
# Got latitude from reflat for par17
# Got longitude from reflon for par17
# Got elevation from refelev for par17
# Read in edi file for station par17
# Got latitude from reflat for par17ew
# Got longitude from reflon for par17ew
# Got elevation from refelev for par17ew
# Read in edi file for station par17ew
# Got latitude from reflat for par18
# Got longitude from reflon for par18
# Got elevation from refelev for par18
# Read in edi file for station par18
# Got latitude from reflat for par18ew
# Got longitude from reflon for par18ew
# Got elevation from refelev for par18ew
# Read in edi file for station par18ew
# Got latitude from reflat for par19
# Got longitude from reflon for par19
# Got elevation from refelev for par19
# Read in edi file for station par19
# Got latitude from reflat for par19ew
# Got longitude from reflon for par19ew
# Got elevation from refelev for par19ew
# Read in edi file for station par19ew
# Got latitude from reflat for par20
# Got longitude from reflon for par20
# Got elevation from refelev for par20
# Read in edi file for station par20
# Got latitude from reflat for par20ew
# Got longitude from reflon for par20ew
# Got elevation from refelev for par20ew
# Read in edi file for station par20ew
# Got latitude from reflat for par21
# Got longitude from reflon for par21
# Got elevation from refelev for par21
# Read in edi file for station par21
# Got latitude from reflat for par210
# Got longitude from reflon for par210
# Got elevation from refelev for par210
# Read in edi file for station par210
# Got latitude from reflat for par21ew
# Got longitude from reflon for par21ew
# Got elevation from refelev for par21ew
# Read in edi file for station par21ew
# Got latitude from reflat for par22
# Got longitude from reflon for par22
# Got elevation from refelev for par22
# Read in edi file for station par22
# Got latitude from reflat for par22ew
# Got longitude from reflon for par22ew
# Got elevation from refelev for par22ew
# Read in edi file for station par22ew
# Got latitude from reflat for par23
# Got longitude from reflon for par23
# Got elevation from refelev for par23
# Read in edi file for station par23
# Got latitude from reflat for par23ew
# Got longitude from reflon for par23ew
# Got elevation from refelev for par23ew
# Read in edi file for station par23ew
# Got latitude from reflat for par24
# Got longitude from reflon for par24
# Got elevation from refelev for par24
# Read in edi file for station par24
# Got latitude from reflat for par24ew
# Got longitude from reflon for par24ew
# Got elevation from refelev for par24ew
# Read in edi file for station par24ew
# Got latitude from reflat for par25ew
# Got longitude from reflon for par25ew
# Got elevation from refelev for par25ew
# Read in edi file for station par25ew
# Got latitude from reflat for par26
# Got longitude from reflon for par26
# Got elevation from refelev for par26
# Read in edi file for station par26
# Got latitude from reflat for par26ew
# Got longitude from reflon for par26ew
# Got elevation from refelev for par26ew
# Read in edi file for station par26ew
# Got latitude from reflat for par27
# Got longitude from reflon for par27
# Got elevation from refelev for par27
# Read in edi file for station par27
# Got latitude from reflat for par27ew
# Got longitude from reflon for par27ew
# Got elevation from refelev for par27ew
# Read in edi file for station par27ew
# Got latitude from reflat for par28
# Got longitude from reflon for par28
# Got elevation from refelev for par28
# Read in edi file for station par28
# Got latitude from reflat for par28ew
# Got longitude from reflon for par28ew
# Got elevation from refelev for par28ew
# Read in edi file for station par28ew
# Got latitude from reflat for par29
# Got longitude from reflon for par29
# Got elevation from refelev for par29
# Read in edi file for station par29
# Got latitude from reflat for par29ew
# Got longitude from reflon for par29ew
# Got elevation from refelev for par29ew
# Read in edi file for station par29ew
# Got latitude from reflat for par30
# Got longitude from reflon for par30
# Got elevation from refelev for par30
# Read in edi file for station par30
# Got latitude from reflat for par30ew
# Got longitude from reflon for par30ew
# Got elevation from refelev for par30ew
# Read in edi file for station par30ew
# Got latitude from reflat for par31
# Got longitude from reflon for par31
# Got elevation from refelev for par31
# Read in edi file for station par31
# Got latitude from reflat for par310
# Got longitude from reflon for par310
# Got elevation from refelev for par310
# Read in edi file for station par310
# Got latitude from reflat for par31ew
# Got longitude from reflon for par31ew
# Got elevation from refelev for par31ew
# Read in edi file for station par31ew
# Got latitude from reflat for par32
# Got longitude from reflon for par32
# Got elevation from refelev for par32
# Read in edi file for station par32
# Got latitude from reflat for par33
# Got longitude from reflon for par33
# Got elevation from refelev for par33
# Read in edi file for station par33
# Got latitude from reflat for par34
# Got longitude from reflon for par34
# Got elevation from refelev for par34
# Read in edi file for station par34
# Got latitude from reflat for par36
# Got longitude from reflon for par36
# Got elevation from refelev for par36
# Read in edi file for station par36
# Got latitude from reflat for par37
# Got longitude from reflon for par37
# Got elevation from refelev for par37
# Read in edi file for station par37
# Got latitude from reflat for par38
# Got longitude from reflon for par38
# Got elevation from refelev for par38
# Read in edi file for station par38
# Got latitude from reflat for par39
# Got longitude from reflon for par39
# Got elevation from refelev for par39
# Read in edi file for station par39
# Got latitude from reflat for par40
# Got longitude from reflon for par40
# Got elevation from refelev for par40
# Read in edi file for station par40
# Got latitude from reflat for par41
# Got longitude from reflon for par41
# Got elevation from refelev for par41
# Read in edi file for station par41
# Got latitude from reflat for par410
# Got longitude from reflon for par410
# Got elevation from refelev for par410
# Read in edi file for station par410
# Got latitude from reflat for par42
# Got longitude from reflon for par42
# Got elevation from refelev for par42
# Read in edi file for station par42
# Got latitude from reflat for par43
# Got longitude from reflon for par43
# Got elevation from refelev for par43
# Read in edi file for station par43
# Got latitude from reflat for par44
# Got longitude from reflon for par44
# Got elevation from refelev for par44
# Read in edi file for station par44
# Got latitude from reflat for par46
# Got longitude from reflon for par46
# Got elevation from refelev for par46
# Read in edi file for station par46
# Got latitude from reflat for par47
# Got longitude from reflon for par47
# Got elevation from refelev for par47
# Read in edi file for station par47
# Got latitude from reflat for par48
# Got longitude from reflon for par48
# Got elevation from refelev for par48
# Read in edi file for station par48
# Got latitude from reflat for par49
# Got longitude from reflon for par49
# Got elevation from refelev for par49
# Read in edi file for station par49
# Got latitude from reflat for par50
# Got longitude from reflon for par50
# Got elevation from refelev for par50
# Read in edi file for station par50
# Got latitude from reflat for par51
# Got longitude from reflon for par51
# Got elevation from refelev for par51
# Read in edi file for station par51
# Got latitude from reflat for par510
# Got longitude from reflon for par510
# Got elevation from refelev for par510
# Read in edi file for station par510
# Got latitude from reflat for par52
# Got longitude from reflon for par52
# Got elevation from refelev for par52
# Read in edi file for station par52
# Got latitude from reflat for par53
# Got longitude from reflon for par53
# Got elevation from refelev for par53
# Read in edi file for station par53
# Got latitude from reflat for par54
# Got longitude from reflon for par54
# Got elevation from refelev for par54
# Read in edi file for station par54
# Got latitude from reflat for par56
# Got longitude from reflon for par56
# Got elevation from refelev for par56
# Read in edi file for station par56
# Got latitude from reflat for par57
# Got longitude from reflon for par57
# Got elevation from refelev for par57
# Read in edi file for station par57
# Got latitude from reflat for par58
# Got longitude from reflon for par58
# Got elevation from refelev for par58
# Read in edi file for station par58
# Got latitude from reflat for par59
# Got longitude from reflon for par59
# Got elevation from refelev for par59
# Read in edi file for station par59
# Got latitude from reflat for par60
# Got longitude from reflon for par60
# Got elevation from refelev for par60
# Read in edi file for station par60
# Got latitude from reflat for par61
# Got longitude from reflon for par61
# Got elevation from refelev for par61
# Read in edi file for station par61
# Got latitude from reflat for par610
# Got longitude from reflon for par610
# Got elevation from refelev for par610
# Read in edi file for station par610
# Got latitude from reflat for par62
# Got longitude from reflon for par62
# Got elevation from refelev for par62
# Read in edi file for station par62
# Got latitude from reflat for par63
# Got longitude from reflon for par63
# Got elevation from refelev for par63
# Read in edi file for station par63
# Got latitude from reflat for par64
# Got longitude from reflon for par64
# Got elevation from refelev for par64
# Read in edi file for station par64
# Got latitude from reflat for par66
# Got longitude from reflon for par66
# Got elevation from refelev for par66
# Read in edi file for station par66
# Got latitude from reflat for par67
# Got longitude from reflon for par67
# Got elevation from refelev for par67
# Read in edi file for station par67
# Got latitude from reflat for par68
# Got longitude from reflon for par68
# Got elevation from refelev for par68
# Read in edi file for station par68
# Got latitude from reflat for par69
# Got longitude from reflon for par69
# Got elevation from refelev for par69
# Read in edi file for station par69
# Got latitude from reflat for par70
# Got longitude from reflon for par70
# Got elevation from refelev for par70
# Read in edi file for station par70
# Got latitude from reflat for par71
# Got longitude from reflon for par71
# Got elevation from refelev for par71
# Read in edi file for station par71
# Got latitude from reflat for par710
# Got longitude from reflon for par710
# Got elevation from refelev for par710
# Read in edi file for station par710
# Got latitude from reflat for par72
# Got longitude from reflon for par72
# Got elevation from refelev for par72
# Read in edi file for station par72
# Got latitude from reflat for par73
# Got longitude from reflon for par73
# Got elevation from refelev for par73
# Read in edi file for station par73
# Got latitude from reflat for par74
# Got longitude from reflon for par74
# Got elevation from refelev for par74
# Read in edi file for station par74
# Got latitude from reflat for par76
# Got longitude from reflon for par76
# Got elevation from refelev for par76
# Read in edi file for station par76
# Got latitude from reflat for par77
# Got longitude from reflon for par77
# Got elevation from refelev for par77
# Read in edi file for station par77
# Got latitude from reflat for par78
# Got longitude from reflon for par78
# Got elevation from refelev for par78
# Read in edi file for station par78
# Got latitude from reflat for par79
# Got longitude from reflon for par79
# Got elevation from refelev for par79
# Read in edi file for station par79
# Got latitude from reflat for par80
# Got longitude from reflon for par80
# Got elevation from refelev for par80
# Read in edi file for station par80
# Got latitude from reflat for par81
# Got longitude from reflon for par81
# Got elevation from refelev for par81
# Read in edi file for station par81
# Got latitude from reflat for par810
# Got longitude from reflon for par810
# Got elevation from refelev for par810
# Read in edi file for station par810
# Got latitude from reflat for par82
# Got longitude from reflon for par82
# Got elevation from refelev for par82
# Read in edi file for station par82
# Got latitude from reflat for par83
# Got longitude from reflon for par83
# Got elevation from refelev for par83
# Read in edi file for station par83
# Got latitude from reflat for par84
# Got longitude from reflon for par84
# Got elevation from refelev for par84
# Read in edi file for station par84
# Got latitude from reflat for par86
# Got longitude from reflon for par86
# Got elevation from refelev for par86
# Read in edi file for station par86
# Got latitude from reflat for par87
# Got longitude from reflon for par87
# Got elevation from refelev for par87
# Read in edi file for station par87
# Got latitude from reflat for par88
# Got longitude from reflon for par88
# Got elevation from refelev for par88
# Read in edi file for station par88
# Got latitude from reflat for par89
# Got longitude from reflon for par89
# Got elevation from refelev for par89
# Read in edi file for station par89
# Got latitude from reflat for par90
# Got longitude from reflon for par90
# Got elevation from refelev for par90
# Read in edi file for station par90
# Got latitude from reflat for par91
# Got longitude from reflon for par91
# Got elevation from refelev for par91
# Read in edi file for station par91
# Got latitude from reflat for par910
# Got longitude from reflon for par910
# Got elevation from refelev for par910
# Read in edi file for station par910
# Got latitude from reflat for par92
# Got longitude from reflon for par92
# Got elevation from refelev for par92
# Read in edi file for station par92
# Got latitude from reflat for par93
# Got longitude from reflon for par93
# Got elevation from refelev for par93
# Read in edi file for station par93
# Got latitude from reflat for par94
# Got longitude from reflon for par94
# Got elevation from refelev for par94
# Read in edi file for station par94
# Got latitude from reflat for par96
# Got longitude from reflon for par96
# Got elevation from refelev for par96
# Read in edi file for station par96
# Got latitude from reflat for par97
# Got longitude from reflon for par97
# Got elevation from refelev for par97
# Read in edi file for station par97
# Got latitude from reflat for par98
# Got longitude from reflon for par98
# Got elevation from refelev for par98
# Read in edi file for station par98
# Got latitude from reflat for par99
# Got longitude from reflon for par99
# Got elevation from refelev for par99
# Read in edi file for station par99
# Reading 183 stations
# Could not plot image

# %% [markdown]
# * learn more about plot_pt_map object

# %%
help(ptm)
# Out:
# Help on PlotPhaseTensorMaps in module mtpy.imaging.plotptmaps object:
#
# class PlotPhaseTensorMaps(mtpy.imaging.mtplottools.MTArrows, mtpy.imaging.mtplottools.MTEllipse)
#  |  Plots phase tensor ellipses in map view from a list of edifiles with full
#  |  path.
#  |
#  |  Arguments:
#  |  -------------
#  |
#  |      **fn_list** : list of strings
#  |                        full paths to .edi files to plot
#  |
#  |      **z_object** : class mtpy.core.z.Z
#  |                    object of mtpy.core.z.  If this is input be sure the
#  |                    attribute z.freq is filled.  *default* is None
#  |
#  |      **mt_object** : class mtpy.imaging.mtplot.MTplot
#  |                      object of mtpy.imaging.mtplot.MTplot
#  |                      *default* is None
#  |
#  |      **pt_object** : class mtpy.analysis.pt
#  |                      phase tensor object of mtpy.analysis.pt.  If this is
#  |                      input then the ._mt attribute is set to None cause
#  |                      at the moment cannot tranform the phase tensor to z
#  |                      *default* is None
#  |
#  |      **plot_freq** : float
#  |                           freq to plot in Hz
#  |                           *default* is 1
#  |
#  |      **ftol** : float
#  |                 tolerance in freq range to look for in each file.
#  |                 *default* is 0.1 (10 percent)
#  |
#  |      **ellipse_dict** : dictionary
#  |                        dictionary of parameters for the phase tensor
#  |                        ellipses with keys:
#  |                            * 'size' -> size of ellipse in points
#  |                                       *default* is 2
#  |
#  |                            * 'colorby' : [ 'phimin' | 'phimax' | 'skew' |
#  |                                            'skew_seg' | 'phidet' |
#  |                                            'ellipticity' ]
#  |
#  |                                      - 'phimin' -> colors by minimum phase
#  |                                      - 'phimax' -> colors by maximum phase
#  |                                      - 'skew' -> colors by skew
#  |                                      - 'skew_seg' -> colors by skew in
#  |                                                     discrete segments
#  |                                                     defined by the range
#  |                                      - 'normalized_skew' -> colors by skew
#  |                                              see [Booker, 2014]
#  |                                      - 'normalized_skew_seg' -> colors by
#  |                                                     normalized skew in
#  |                                                     discrete segments
#  |                                                     defined by the range
#  |                                      - 'phidet' -> colors by determinant of
#  |                                                   the phase tensor
#  |                                      - 'ellipticity' -> colors by ellipticity
#  |                                      *default* is 'phimin'
#  |
#  |                             * 'range' : tuple (min, max, step)
#  |                                   Need to input at least the min and max
#  |                                   and if using 'skew_seg' to plot
#  |                                   discrete values input step as well
#  |                                   *default* depends on 'colorby'
#  |
#  |                        * 'cmap' : [ 'mt_yl2rd' | 'mt_bl2yl2rd' |
#  |                                    'mt_wh2bl' | 'mt_rd2bl' |
#  |                                    'mt_bl2wh2rd' | 'mt_seg_bl2wh2rd' |
#  |                                    'mt_rd2gr2bl' ]
#  |
#  |                                 - 'mt_yl2rd' -> yellow to red
#  |                                 - 'mt_bl2yl2rd' -> blue to yellow to red
#  |                                 - 'mt_wh2bl' -> white to blue
#  |                                 - 'mt_rd2bl' -> red to blue
#  |                                 - 'mt_bl2wh2rd' -> blue to white to red
#  |                                 - 'mt_bl2gr2rd' -> blue to green to red
#  |                                 - 'mt_rd2gr2bl' -> red to green to blue
#  |                                 - 'mt_seg_bl2wh2rd' -> discrete blue to
#  |                                                       white to red
#  |
#  |
#  |      **cb_dict** : dictionary to control the color bar
#  |
#  |                    * 'orientation' : [ 'vertical' | 'horizontal' ]
#  |                                     orientation of the color bar
#  |                                     *default* is vertical
#  |
#  |                    * 'position' : tuple (x,y,dx,dy)
#  |                                  - x -> lateral position of left hand corner
#  |                                        of the color bar in figure between
#  |                                        [0,1], 0 is left side
#  |
#  |                                  - y -> vertical position of the bottom of
#  |                                        the color bar in figure between
#  |                                        [0,1], 0 is bottom side.
#  |
#  |                                  - dx -> width of the color bar [0,1]
#  |
#  |                                  - dy -> height of the color bar [0,1]
#  |
#  |      **arrow_dict** : dictionary for arrow properties
#  |                      * 'size' : float
#  |                                multiplier to scale the arrow. *default* is 5
#  |                      * 'head_length' : float
#  |                                       length of the arrow head *default* is
#  |                                       1.5
#  |                      * 'head_width' : float
#  |                                      width of the arrow head *default* is
#  |                                      1.5
#  |                      * 'lw' : float
#  |                              line width of the arrow *default* is .5
#  |
#  |                      * 'color' : tuple (real, imaginary)
#  |                                 color of the arrows for real and imaginary
#  |
#  |                      * 'threshold': float
#  |                                    threshold of which any arrow larger than
#  |                                    this number will not be plotted, helps
#  |                                    clean up if the data is not good.
#  |                                    *default* is 1, note this is before
#  |                                    scaling by 'size'
#  |
#  |                      * 'direction : [ 0 | 1 ]
#  |                                   - 0 for arrows to point toward a conductor
#  |                                   - 1 for arrow to point away from conductor
#  |
#  |      **xpad** : float
#  |                 padding in the east-west direction of plot boundaries.  Note
#  |                 this is by default set to lat and long units, so if you use
#  |                 easting/northing put it the respective units.
#  |                 *default* is 0.2
#  |
#  |      **pad** : float
#  |                 padding in the north-south direction of plot boundaries.
#  |                 Note this is by default set to lat and long units, so if you
#  |                 use easting/northing put it the respective units.
#  |                 *default* is 0.2
#  |
#  |      **rotz** : float
#  |                 angle in degrees to rotate the data clockwise positive.
#  |                 *Default* is 0
#  |
#  |      **figsize** : tuple or list (x, y) in inches
#  |                    dimensions of the figure box in inches, this is a default
#  |                    unit of matplotlib.  You can use this so make the plot
#  |                    fit the figure box to minimize spaces from the plot axes
#  |                    to the figure box.  *default* is [8, 8]
#  |
#  |      **station_dict** : dictionary
#  |                          * 'id' --> for station id index.  Ex: If you want
#  |                                    'S01' from 'S01dr' input as (0,3).
#  |
#  |                          * 'pad' --> pad from the center of the ellipse to
#  |                                     the station label
#  |
#  |                          * 'font_dict'--> dictionary of font properties
#  |                                         font dictionary for station name.
#  |                                         Keys can be matplotlib.text
#  |                                         properties, common ones are:
#  |                                         * 'size'   -> for font size
#  |                                         * 'weight' -> for font weight
#  |                                         * 'color'  -> for color of font
#  |                                         * 'angle'  -> for angle of text
#  |
#  |      **tscale** : [ 'period' | 'freq' ]
#  |
#  |                   * 'period'    -> plot vertical scale in period
#  |
#  |                   * 'freq' -> plot vertical scale in freq
#  |
#  |      **mapscale** : [ 'deg' | 'm' | 'km' ]
#  |                     Scale of the map coordinates.
#  |
#  |                     * 'deg' --> degrees in latitude and longitude
#  |
#  |                     * 'm' --> meters for easting and northing
#  |
#  |                     * 'km' --> kilometers for easting and northing
#  |
#  |      **image_dict** : dictionary of image properties
#  |
#  |                       * 'file' : string
#  |                                 full path to image file name
#  |
#  |                       * 'extent' : tuple (xmin, xmax, ymin, ymax)
#  |                                   coordinates according to mapscale. Must be
#  |                                   input if image file is not None.
#  |
#  |      **plot_yn** : [ 'y' | 'n' ]
#  |                    *'y' to plot on creating an instance
#  |
#  |                    *'n' to not plot on creating an instance
#  |
#  |      **fignum** : int
#  |                   figure number.  *Default* is 1
#  |
#  |      **title** : string
#  |                  figure title
#  |
#  |      **dpi** : int
#  |                dots per inch of the resolution. *default* is 300
#  |
#  |      **plot_tipper** : [ 'yri' | 'yr' | 'yi' | 'n' ]
#  |                      * 'yri' to plot induction both real and imaginary
#  |                         induction arrows
#  |
#  |                      * 'yr' to plot just the real induction arrows
#  |
#  |                      * 'yi' to plot the imaginary induction arrows
#  |
#  |                      * 'n' to not plot them
#  |
#  |                      * *Default* is 'n'
#  |
#  |                      **Note: convention is to point towards a conductor but
#  |                      can be changed in arrow_dict['direction']**
#  |
#  |
#  |      **font_size** : float
#  |                      size of the font that labels the plot, 2 will be added
#  |                      to this number for the axis labels.
#  |
#  |
#  |      **station_dict** : dictionary
#  |                         font dictionary for station name. Keys can be
#  |                         matplotlib.text properties, common ones are:
#  |                             * 'size'   -> for font size
#  |                             * 'weight' -> for font weight
#  |                             * 'color'  -> for color of font
#  |
#  |      **arrow_legend_dict** : dictionary of properties for legend with keys:
#  |                             * 'position' -> placement of arrow legend can be:
#  |                                 - 'upper right'
#  |                                 - 'lower right'
#  |                                 - 'upper left'
#  |                                 - 'lower left'
#  |                             * 'xborderpad'-> padding from x axis
#  |                             * 'yborderpad'-> padding from y axis
#  |                             *'fontpad'   -> padding between arrow and
#  |                                             legend text
#  |                             * 'fontdict'  -> dictionary of font properties
#  |
#  |
#  |
#  |      **reference_point** : tuple (x0,y0)
#  |                            reference point estimate relative distance to.
#  |                            This point will be (0,0) on the map and
#  |                            everything else is referenced to this point
#  |
#  |  :Example: ::
#  |
#  |      >>> import mtpy.imaging.mtplot as mtplot
#  |      >>> import os
#  |      >>> edipath = r"/home/EDIfiles"
#  |      >>> edilist = [os.path.join(edipath,edi) for edi in os.listdir(edipath)
#  |      >>> ...       if edi.find('.edi')>0]
#  |      >>> # color by phimin with a range of 20-70 deg
#  |      >>> ptmap = mtplot.plot_pt_map(fn_list=edilist,freqspot=10,
#  |      >>> ...                                ellipse_dict={'size':1,
#  |      >>> ...                                              'range':(20,70)})
#  |      >>>
#  |      >>> #----add real induction arrows----
#  |      >>> ptmap.plot_tipper = 'yr'
#  |      >>> ptmap.redraw_plot()
#  |      >>> #
#  |      >>> #---change the arrow properties---
#  |      >>> ptmap.arrow_size = 1
#  |      >>> ptmap.arrow_head_width = 0.25
#  |      >>> ptmap.arrow_head_length = 0.25
#  |      >>> ptmap.arrow_lw = .5
#  |      >>> ptmap.redraw_plot()
#  |      >>> #
#  |      >>> #---add an image---
#  |      >>> ptmap.image_file = r"/home/Maps/Basemap.jpg"
#  |      >>> ptmap.image_extent = (0,10,0,10)
#  |      >>> ptmap.redraw_plot()
#  |      >>> #
#  |      >>> #---Save the plot---
#  |      >>> ptmap.save_plot(r"/home/EDIfiles",file_format='pdf')
#  |      >>> 'Saved figure to /home/EDIfile/PTMaps/PTmap_phimin_10.0_Hz.pdf'
#  |
#  |  :Example: ::
#  |
#  |      >>> #change the axis label and grid color
#  |      >>> ptmap.ax.set_xlabel('Latitude (deg)')
#  |      >>> ptmap.ax.grid(which='major', color=(.5,1,0))
#  |      >>> ptmap.update_plot()
#  |
#  |  Attributes:
#  |  --------------
#  |
#  |      -arrow_color_imag         imaginary induction arrow color
#  |      -arrow_color_real         real induction arrow color
#  |      -arrow_direction          directional convention of arrows
#  |      -arrow_head_length        head length of arrows in relative points
#  |      -arrow_head_width         head width of arrows in relative points
#  |      -arrow_legend_fontdict    font dictionary for arrow legend
#  |      -arrow_legend_fontpad     padding between font of legend and arrow
#  |      -arrow_legend_position    legend position see matplotlib.legend
#  |      -arrow_legend_xborderpad  padding between legend and x axis
#  |      -arrow_legend_yborderpad  padding between legend and y axis
#  |      -arrow_lw                 arrow line width
#  |      -arrow_size               scaling factor to make arrows visible
#  |      -arrow_threshold          threshold for plotting arrows anything above
#  |                                this number will not be plotted
#  |
#  |      -ax                   matplotlib.axes instance for the main plot
#  |      -ax2                  matplotlib.axes instance for the color bar
#  |      -cb                   matplotlib.colors.ColorBar instance for color bar
#  |      -cb_orientation       color bar orientation ('vertical' | 'horizontal')
#  |      -cb_position          color bar position (x, y, dx, dy)
#  |
#  |      -dpi                  dots-per-inch resolution
#  |
#  |      -ellipse_cmap         ellipse color map, see above for options
#  |      -ellipse_colorby      parameter to color ellipse by
#  |      -ellipse_range        (min, max, step) values to color ellipses
#  |      -ellipse_size         scaling factor to make ellipses visible
#  |
#  |      -fig                  matplotlib.figure instance for the figure
#  |      -fignum               number of figure being plotted
#  |      -figsize              size of figure in inches
#  |      -font_size            font size of axes tick label, axes labels will be
#  |                            font_size + 2
#  |
#  |      -ftol                 tolerance to look for matching freq
#  |      -jj                   index of plot freq
#  |
#  |      -mapscale             scale of map
#  |
#  |      -mt_list               list of mtplot.MTplot instances containing all
#  |                            the important information for each station
#  |
#  |      -plot_freq       freq in Hz to plot
#  |      -plot_reference_point  reference point of map, everything will be
#  |                             measured relative to this point
#  |      -plot_tipper           string to indicate to plot induction arrows
#  |
#  |      -plot_xarr            array of x-coordinates for stations
#  |      -plot_yarr            array of y-coordinates for stations
#  |      -plot_yn              plot on instance creation
#  |
#  |      -rot_z                rotates the data by this angle assuming North is
#  |                            0 and angle measures clockwise
#  |
#  |      -tickstrfmt           format of tick strings
#  |      -title                title of figure
#  |      -tscale               temporal scale of y-axis ('freq' | 'period')
#  |      -xpad                 padding between furthest station in x-direction
#  |                            and the axes edge
#  |      -ypad                 padding between furthes station in y-direction
#  |                            and axes edge
#  |
#  |  Methods:
#  |  ----------
#  |
#  |      -plot                 plots the pseudo section
#  |      -redraw_plot          on call redraws the plot from scratch
#  |      -save_figure          saves figure to a file of given format
#  |      -update_plot          updates the plot while still active
#  |      -writeTextFiles       writes parameters of the phase tensor and tipper
#  |                            to text files.
#  |
#  |  Method resolution order:
#  |      PlotPhaseTensorMaps
#  |      mtpy.imaging.mtplottools.MTArrows
#  |      mtpy.imaging.mtplottools.MTEllipse
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, **kwargs)
#  |
#  |  __str__(self)
#  |      rewrite the string builtin to give a useful message
#  |
#  |  plot(self)
#  |      Plots the phase tensor map
#  |
#  |  redraw_plot(self)
#  |      use this function if you updated some attributes and want to re-plot.
#  |
#  |      :Example: ::
#  |
#  |          >>> # change the color and marker of the xy components
#  |          >>> import mtpy.imaging.mtplottools as mtplot
#  |          >>> p1 = mtplot.PlotResPhase(r'/home/MT/mt01.edi')
#  |          >>> p1.xy_color = (.5,.5,.9)
#  |          >>> p1.xy_marker = '*'
#  |          >>> p1.redraw_plot()
#  |
#  |  save_figure(self, save_fn, file_format='pdf', orientation='portrait', fig_dpi=None, close_plot='y')
#  |      save_plot will save the figure to save_fn.
#  |
#  |      Arguments:
#  |      -----------
#  |
#  |          **save_fn** : string
#  |                        full path to save figure to, can be input as
#  |                        * directory path -> the directory path to save to
#  |                          in which the file will be saved as
#  |                          save_fn/station_name_ResPhase.file_format
#  |
#  |                        * full path -> file will be save to the given
#  |                          path.  If you use this option then the format
#  |                          will be assumed to be provided by the path
#  |
#  |          **file_format** : [ pdf | eps | jpg | png | svg ]
#  |                            file type of saved figure pdf,svg,eps...
#  |
#  |          **orientation** : [ landscape | portrait ]
#  |                            orientation in which the file will be saved
#  |                            *default* is portrait
#  |
#  |          **fig_dpi** : int
#  |                        The resolution in dots-per-inch the file will be
#  |                        saved.  If None then the dpi will be that at
#  |                        which the figure was made.  I don't think that
#  |                        it can be larger than dpi of the figure.
#  |
#  |          **close_plot** : [ y | n ]
#  |                           * 'y' will close the plot after saving.
#  |                           * 'n' will leave plot open
#  |
#  |      :Example: ::
#  |
#  |          >>> # to save plot as jpg
#  |          >>> import mtpy.imaging.mtplottools as mtplot
#  |          >>> p1 = mtplot.PlotPhaseTensorMaps(edilist,freqspot=10)
#  |          >>> p1.save_plot(r'/home/MT', file_format='jpg')
#  |          'Figure saved to /home/MT/PTMaps/PTmap_phimin_10Hz.jpg'
#  |
#  |  update_plot(self)
#  |      update any parameters that where changed using the built-in draw from
#  |      canvas.
#  |
#  |      Use this if you change an of the .fig or axes properties
#  |
#  |      :Example: ::
#  |
#  |          >>> # to change the grid lines to only be on the major ticks
#  |          >>> import mtpy.imaging.mtplottools as mtplot
#  |          >>> p1 = mtplot.PlotResPhase(r'/home/MT/mt01.edi')
#  |          >>> [ax.grid(True, which='major') for ax in [p1.axr,p1.axp]]
#  |          >>> p1.update_plot()
#  |
#  |  writeTextFiles(self, save_path=None)
#  |      This will write text files for all the phase tensor parameters.
#  |
#  |      Arguments:
#  |      ----------
#  |          **save_path** : string
#  |                          path to save files to.  Files are saved as:
#  |                              save_path/Map_freq.parameter
#  |
#  |      Returns:
#  |      --------
#  |          **files for:**
#  |              *phi_min
#  |              *phi_max
#  |              *skew
#  |              *ellipticity
#  |              *azimuth
#  |              *tipper_mag_real
#  |              *tipper_ang_real
#  |              *tipper_mag_imag
#  |              *tipper_ang_imag
#  |              *station
#  |
#  |          These files are in condensed map view to follow the plot.  There
#  |          is also a file that is in table format, which might be easier
#  |          to read.  This file has extenstion .table
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  rot_z
#  |      rotation angle(s)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from mtpy.imaging.mtplottools.MTArrows:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# * Adjust parameters to make it look nice

# %%
ptm.fig_size = [6, 6]    # figure size so it fits in the window
ptm.ellipse_size = .005  # ellipse size
ptm.xpad = -.035           # padding between last ellipse and plot border in x-direction
ptm.ypad = -.035           # padding between last ellipse and plot border in y-direction
ptm.plot_freq = 10       # change the plot frequency to a value that shows something interesting
ptm.redraw_plot()
# Out:
# Could not plot image

# %% [markdown]
# * add in tipper data

# %%
ptm.plot_tipper = 'yri'       # plot real 'r' and imaginary 'i' parts
ptm.arrow_head_length = .001
ptm.arrow_head_width = .0005
ptm.arrow_head_height = .0005
ptm.arrow_lw = .5
ptm.arrow_size = ptm.ellipse_size
ptm.arrow_legend_xborderpad = .0075
ptm.arrow_legend_yborderpad = .0075
ptm.arrow_legend_fontpad = .005
ptm.redraw_plot()
# Out:
# Could not plot image

# %% [markdown]
# * plot phase tensor skew

# %%
ptm.ellipse_colorby = 'skew_seg'       # skew angle that is segmented into color bins
ptm.ellipse_cmap = 'mt_seg_bl2wh2rd'   # blue to white to red segmented colors
ptm.ellipse_range = (-6, 6, 2)         # range of skew values
ptm.redraw_plot()
# Out:
# Could not plot image
